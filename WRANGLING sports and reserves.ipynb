# %% [markdown]
# 1. import libaries
# 2. data inspection
#
#     check the unique ID
#
#     check null values
#
#     check sports types in data sets

# %%
import pandas as pd
import numpy as np
import requests

# %%
data = pd.read_csv('SportandRec.csv')
data.head()
# Out:
#             X          Y  OBJECTID  Facility_ID  \
# 0  144.640316 -37.898601      9001   WYNDHA8530
# 1  144.727500 -37.872000      9002  WYNDHA11288
# 2  144.659074 -37.913492      9003   WYNDHA8521
# 3  144.674980 -37.924111      9004   WYNDHA8516
# 4  144.717830 -37.840037      9005   WYNDHA5496
#
#                        FacilityName StreetNo StreetName StreetType  \
# 0  Werribee Sports & Fitness Centre      NaN     Ballan       Road
# 1             Hoppers Indoor Sportz      NaN     Graham      Court
# 2           Riverside Indoor Sports       13  Riverside     Avenue
# 3        National Equestrian Centre      NaN          K       Road
# 4           Clearwood Drive Reserve      NaN  Clearwood      Drive
#
#          SuburbTown  Postcode   ...      Longitude  FaciltySportPlayedID  \
# 0          WERRIBEE    3030.0   ...     144.640316                 26686
# 1  HOPPERS CROSSING    3029.0   ...     144.727500                 26982
# 2          WERRIBEE    3030.0   ...     144.659074                 26667
# 3          WERRIBEE    3030.0   ...     144.674980                 26653
# 4         TRUGANINA       NaN   ...     144.717830                 27809
#
#        SportsPlayed NumberFieldCourts        FieldSurfaceType  FacilityAge  \
# 0           Netball               5.0              Hard Court          NaN
# 1  Netball (indoor)               2.0                     NaN          NaN
# 2  Netball (Indoor)               5.0  Carpet Playing Surface          NaN
# 3              Polo               2.0                     NaN          NaN
# 4      Rugby League               2.0                     NaN  0 - 5 Years
#
#   FacilityCondition               FacilityUpgradeAge   Changerooms      LGA
# 0           4. Good                              NaN  Female, Male  WYNDHAM
# 1               NaN                              NaN           NaN  WYNDHAM
# 2               NaN                              NaN           NaN  WYNDHAM
# 3               NaN                              NaN           NaN  WYNDHAM
# 4               NaN  New facility under construction           NaN  WYNDHAM
#
# [5 rows x 21 columns]

# %%
# data inspection
data.shape
# more than 9,000 records
# Out:
# (9471, 21)

# %%
# check null values
data.isnull().any()
# Out:
# X                       False
# Y                       False
# OBJECTID                False
# Facility_ID             False
# FacilityName            False
# StreetNo                 True
# StreetName               True
# StreetType               True
# SuburbTown               True
# Postcode                 True
# Latitude                False
# Longitude               False
# FaciltySportPlayedID    False
# SportsPlayed             True
# NumberFieldCourts        True
# FieldSurfaceType         True
# FacilityAge              True
# FacilityCondition        True
# FacilityUpgradeAge       True
# Changerooms              True
# LGA                     False
# dtype: bool

# %%
# check various ID feature in dataframe
# see which one can be a unique key in database

# OBJECTID
print('count for OBJECTID', len(data.OBJECTID.unique()))

# Facility_ID
print('count for Unique Facility_ID', len(data.Facility_ID.unique()))

# FacilitySportPlayedID
print('count for facilitySportPlayID', len(data.FaciltySportPlayedID.unique()))

# FacilityName
print('count for facilityname', len(data.FacilityName.unique()))

# X
print('count for X', len(data.X.unique()))

# Y
print('count for Y', len(data.Y.unique()))

# longitude
print('count for longitude', len(data.Longitude.unique()))
      
# Latitude
print('count for latitude', len(data.Latitude.unique()))


# OBJECTID and FacilitySportPlayedID are unique
# Out:
# count for OBJECTID 9471
# count for Unique Facility_ID 4940
# count for facilitySportPlayID 9471
# count for facilityname 4841
# count for X 4742
# count for Y 4742
# count for longitude 4728
# count for latitude 4728

# %%
data.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'Facility_ID', 'FacilityName', 'StreetNo',
#        'StreetName', 'StreetType', 'SuburbTown', 'Postcode', 'Latitude',
#        'Longitude', 'FaciltySportPlayedID', 'SportsPlayed',
#        'NumberFieldCourts', 'FieldSurfaceType', 'FacilityAge',
#        'FacilityCondition', 'FacilityUpgradeAge', 'Changerooms', 'LGA'],
#       dtype='object')

# %%
# delete columns so far in this iteration
data.drop(columns=['FaciltySportPlayedID', 'NumberFieldCourts', 'FieldSurfaceType', 'FacilityAge', \
                   'FacilityCondition', 'FacilityUpgradeAge', 'Changerooms'], inplace=True)
# keep only one pair of coordinate
data.drop(columns=['X','Y'], inplace = True)
# do not need ID so far
data.drop(columns=['OBJECTID'], inplace = True)

# %%
data.columns
# Out:
# Index(['Facility_ID', 'FacilityName', 'StreetNo', 'StreetName', 'StreetType',
#        'SuburbTown', 'Postcode', 'Latitude', 'Longitude', 'SportsPlayed',
#        'LGA'],
#       dtype='object')

# %%
# check sports types
count = 0
for i in data.SportsPlayed.unique():
    count += 1
    print(i)
print(count)
# around 85 sports play in the data sets
# Out:
# Netball
# Netball (indoor)
# Netball (Indoor)
# Polo
# Rugby League
# Rugby Union
# Shooting Sports
# Skating
# Soccer
# Soccer (Indoor Soccer / Futsal)
# Softball
# Swimming
# Table Tennis
# Tennis (Outdoor)
# Volleyball
# Athletics
# Australian Rules Football
# Basketball
# BMX
# Bocce
# Boxing
# Canoe Polo
# Canoeing
# Cricket
# Cycling
# Fitness / Gymnasium Workouts
# Gaelic Football
# Golf
# Lawn Bowls
# Martial Arts
# Squash / Racquetball
# Tennis (Indoor)
# Underwater Hockey
# Archery
# Badminton
# Equestrian
# Gymnastics
# Motor Sports
# Sailing
# Cricket (Indoor)
# Croquet
# Hockey
# Dancing
# Jet Skiing
# Modern Pentathlon
# Water Skiing
# nan
# Baseball
# Gridiron
# Karate
# Surf Life Saving
# Tae Kwon Do
# Beach Volleyball
# Diving
# Lacrosse
# Snooker / Billiards / Pool
# Go Karting
# Polocrosse
# Touch Football
# Carpet Bowls
# Australian Rules football
# Rowing
# AFL (Indoor)
# Rock Climbing / Abseiling (Indoor)
# Aerobics
# Motor Cycling
# Ten Pin Bowling
# Disk Golf
# Body Building
# Callisthenics
# soccer
# Fencing
# Rodeo
# Open Space
# Water Polo
# Judo
# Roller Sports - Other
# Tennis (indoor)
# Ice Hockey
# Flying Disk
# Inline Hockey
# Wheelchair Sports
# Orienteering
# Team Handball
# Power Boating
# 85

# %%
# check postcode
data[data.Postcode.isnull()]
# we may need to refill this postcode with Google API
# Out:
#       Facility_ID                                   FacilityName StreetNo  \
# 4      WYNDHA5496                        Clearwood Drive Reserve      NaN
# 55    YARRAC11029                  Collingwood Secondary College      NaN
# 56    YARRAC11032                      Fitzroy Secondary  School      NaN
# 57    YARRAC11028                        Melbourne Girls College      NaN
# 58    YARRAC11030                  Princes Hill Seconary College      NaN
# 59     YARRAC5444                              Lilydale BMX Club      NaN
# 62    YARRAC11024  Melbourne Aboriginal Sport and Recreation Gym      NaN
# 63    YARRAC11023                           Richmond Boxing Club      NaN
# 64    YARRAC11022                            Stanton Street Hall      NaN
# 66    YARRAC11026                           Fairfield Canoe Club        9
# 67    YARRAC11027                  Fairfield Park Canoe Facility      NaN
# 78    YARRAC11021                               Mc Cutcheon Oval      NaN
# 81    YARRAC11020                                        W J COX      NaN
# 85     YARRAC5306                                  Kew Boulevard      NaN
# 86     YARRAC5282                           Yarra Boulevard Loop      NaN
# 118   YARRAC11024  Melbourne Aboriginal Sport and Recreation Gym      NaN
# 124   YARRAC11023                           Richmond Boxing Club      NaN
# 131   YARRAC11022                            Stanton Street Hall      NaN
# 139   YARRAC11021                               Mc Cutcheon Oval      NaN
# 156   YARRAC11028                        Melbourne Girls College      NaN
# 171   YARRAC11021                               Mc Cutcheon Oval      NaN
# 174   YARRAC11029                  Collingwood Secondary College      NaN
# 175   YARRAC11030                  Princes Hill Seconary College      NaN
# 176   YARRAC11031                   Princess Hill Primary School      NaN
# 188   YARRAC11029                  Collingwood Secondary College      NaN
# 225    YARRAR5442                             Eastfield BMX Club      NaN
# 269    YARRAR5421                               Lysterfield Park      NaN
# 493    GANNAW8847                                     Lake Charm      NaN
# 510    GANNAW8847                                     Lake Charm      NaN
# 540    GANNAW8847                                     Lake Charm      NaN
# ...           ...                                            ...      ...
# 9071  MELBOU11014                           Melbourne City Baths      420
# 9072  MELBOU11022              North Melbourne Recreation Centre      206
# 9073  MELBOU11024    Punt rd Recreation Reserve & Community Pool      NaN
# 9074  MELBOU11031                                 Westpac Centre      NaN
# 9075  MELBOU10988                 Carlton Baths Community Centre      248
# 9076  MELBOU10990                    Carlton Gardens Tennis Club       11
# 9077  MELBOU10994                                   Fawkner Park      NaN
# 9078  MELBOU11000                              Flagstaff Gardens      NaN
# 9079  MELBOU11007                   Kensington Banks Tennis Club      NaN
# 9080  MELBOU11017                                 Melbourne Park      NaN
# 9081  MELBOU11023                                   Princes Park      NaN
# 9082  MELBOU11023                                   Princes Park      NaN
# 9083  MELBOU11026                                     Royal Park      NaN
# 9084  MELBOU11026                                     Royal Park      NaN
# 9085  MELBOU10994                                   Fawkner Park      NaN
# 9086  MELBOU11004                                 Goschs Paddock      NaN
# 9087  MELBOU11006                                JJ Holland Park      NaN
# 9088  MELBOU11023                                   Princes Park      NaN
# 9089  MELBOU10988                 Carlton Baths Community Centre      248
# 9090  MELBOU11008         Kensington Community Recreation Centre      NaN
# 9271  MILDUR11276                         Mildura Motocycle Club      NaN
# 9272  MILDUR11278            North West Victorian Motocycle Club      NaN
# 9287   MILDUR5495                          Nichols Point Reserve      NaN
# 9352   MITCHE5377                                     Anvel Loop       82
# 9353   MITCHE5299                                Carlsrushe West      NaN
# 9354   MITCHE5300                              Carlsrushe West 2      NaN
# 9355   MITCHE5305                           Strath Creek Circuit      NaN
# 9356   MITCHE5378                               Talarook Circuit      NaN
# 9378  MITCHE11280                         Seymour Motocycle Club      NaN
# 9379  MITCHE11284               State Motocycling Sports Complex      NaN
#
#                   StreetName    StreetType        SuburbTown  Postcode  \
# 4                  Clearwood         Drive         TRUGANINA       NaN
# 55               Mc Cutcheon           Way       COLLINGWOOD       NaN
# 56                  Falconer        Street           FITZROY       NaN
# 57                     Yarra     Boulevard           BURNLEY       NaN
# 58                    Arnold        Strret      PRINCES HILL       NaN
# 59                  Anderson        Street          LILYDALE       NaN
# 62                  Gertrude        Street           FITZROY       NaN
# 63                  Gleadell        Street          RICHMOND       NaN
# 64                   Stanton        Street       COLLINGWOOD       NaN
# 66             The Esplanade           NaN         FAIRFIELD       NaN
# 67                Heidelberg        Street         FAIRFIELD       NaN
# 78                Yarra Bend          Road         FAIRFIELD       NaN
# 81                Yarra Bend          Road         FAIRFIELD       NaN
# 85                       Kew     Boulevard               KEW       NaN
# 86                     Yarra     Boulevard          RICHMOND       NaN
# 118                 Gertrude        Street           FITZROY       NaN
# 124                 Gleadell        Street          RICHMOND       NaN
# 131                  Stanton        Street       COLLINGWOOD       NaN
# 139               Yarra Bend          Road         FAIRFIELD       NaN
# 156                    Yarra     Boulevard           BURNLEY       NaN
# 171               Yarra Bend          Road         FAIRFIELD       NaN
# 174              Mc Cutcheon           Way       COLLINGWOOD       NaN
# 175                   Arnold        Strret      PRINCES HILL       NaN
# 176                   Pigdon        Street      PRINCES HILL       NaN
# 188              Mc Cutcheon           Way       COLLINGWOOD       NaN
# 225               Colchester          Road           KILSYTH       NaN
# 269                      NaN           NaN               NaN       NaN
# 493               Lake Charm          Road        LAKE CHARM       NaN
# 510               Lake Charm          Road        LAKE CHARM       NaN
# 540               Lake Charm          Road        LAKE CHARM       NaN
# ...                      ...           ...               ...       ...
# 9071                Swanston        Street         MELBOURNE       NaN
# 9072                   Arden        Street   NORTH MELBOURNE       NaN
# 9073                    Punt          Road          RICHMOND       NaN
# 9074                 Olympic     Boulevard         MELBOURNE       NaN
# 9075               Rathdowne        Street           CARLTON       NaN
# 9076               Nicholson        Street         MELBOURNE       NaN
# 9077                  Pasley  Street North       SOUTH YARRA       NaN
# 9078                 William        Street         MELBOURNE       NaN
# 9079                Speakman        Street        KENSINGTON       NaN
# 9080                 Olympic     Boulevard         MELBOURNE       NaN
# 9081                   Royal        Parade         PARKVILLE       NaN
# 9082                   Royal        Parade         PARKVILLE       NaN
# 9083               Macarthur          Road         PARKVILLE       NaN
# 9084               Macarthur          Road         PARKVILLE       NaN
# 9085                  Pasley  Street North       SOUTH YARRA       NaN
# 9086                    Punt          Road          RICHMOND       NaN
# 9087              Kensington          Road  SOUTH KENSINGTON       NaN
# 9088                   Royal        Parade         PARKVILLE       NaN
# 9089               Rathdowne        Street           CARLTON       NaN
# 9090                  Altona        Street        KENSINGTON       NaN
# 9271                Eleventh        Street           MILDURA       NaN
# 9272              Twenthieth        Street           MILDURA       NaN
# 9287                     NaN           NaN               NaN       NaN
# 9352                   Emily        Street           SEYMOUR       NaN
# 9353   Broadford - Glenaroua          Road        CARLSRUSHE       NaN
# 9354      Carlsrushe Central          Road        CARLSRUSHE       NaN
# 9355  Broadford - Flowerdale          Road      STRATH CREEK       NaN
# 9356                 Trawool           NaN          TALAROOK       NaN
# 9378               Telegraph          Road           SEYMOUR       NaN
# 9379    Broadford-Flowerdale          Road         BROADFORD       NaN
#
#        Latitude   Longitude                     SportsPlayed             LGA
# 4    -37.840037  144.717830                     Rugby League         WYNDHAM
# 55   -37.803256  144.989030                       Basketball           YARRA
# 56   -37.800909  144.979157                       Basketball           YARRA
# 57   -37.829690  145.012699                       Basketball           YARRA
# 58   -37.781818  144.966587                       Basketball           YARRA
# 59   -37.748157  145.356706                              BMX    YARRA RANGES
# 62   -37.805467  144.974449                           Boxing           YARRA
# 63   -37.818380  145.001525                           Boxing           YARRA
# 64   -37.801956  144.988164                           Boxing           YARRA
# 66   -37.785639  145.018759                         Canoeing           YARRA
# 67   -37.784370  145.004222                         Canoeing         DAREBIN
# 78   -37.799975  145.008575                          Cricket           YARRA
# 81   -37.799975  145.008575                          Cricket           YARRA
# 85   -37.806529  145.010120                          Cycling      BOROONDARA
# 86   -37.793700  145.015130                          Cycling      BOROONDARA
# 118  -37.805467  144.974449     Fitness / Gymnasium Workouts           YARRA
# 124  -37.818380  145.001525     Fitness / Gymnasium Workouts           YARRA
# 131  -37.801956  144.988164     Fitness / Gymnasium Workouts           YARRA
# 139  -37.799975  145.008575                  Gaelic Football           YARRA
# 156  -37.829690  145.012699                          Netball           YARRA
# 171  -37.799975  145.008575                           Soccer           YARRA
# 174  -37.803256  144.989030  Soccer (Indoor Soccer / Futsal)           YARRA
# 175  -37.781818  144.966587  Soccer (Indoor Soccer / Futsal)           YARRA
# 176  -37.780992  144.962781  Soccer (Indoor Soccer / Futsal)       MELBOURNE
# 188  -37.803256  144.989030                       Volleyball           YARRA
# 225  -37.812005  145.306839                              BMX    YARRA RANGES
# 269  -37.970049  145.301056                          Cycling           CASEY
# 493  -35.604117  143.818022                       Jet Skiing      GANNAWARRA
# 510  -35.604117  143.818022                          Sailing      GANNAWARRA
# 540  -35.604117  143.818022                     Water Skiing      GANNAWARRA
# ...         ...         ...                              ...             ...
# 9071 -37.807035  144.963103                         Swimming       MELBOURNE
# 9072 -37.799291  144.941973                         Swimming       MELBOURNE
# 9073 -37.822304  144.987903                         Swimming       MELBOURNE
# 9074 -37.824674  144.981926                         Swimming       MELBOURNE
# 9075 -37.792875  144.969005                    Team Handball       MELBOURNE
# 9076 -37.802325  144.972860                 Tennis (Outdoor)       MELBOURNE
# 9077 -37.840400  144.981583                 Tennis (Outdoor)       MELBOURNE
# 9078 -37.809912  144.954430                 Tennis (Outdoor)       MELBOURNE
# 9079 -37.794534  144.915836                 Tennis (Outdoor)       MELBOURNE
# 9080 -37.821437  144.979104                 Tennis (Outdoor)       MELBOURNE
# 9081 -37.785105  144.960662                 Tennis (Outdoor)       MELBOURNE
# 9082 -37.785105  144.960662                 Tennis (Outdoor)       MELBOURNE
# 9083 -37.783169  144.949402                 Tennis (Outdoor)       MELBOURNE
# 9084 -37.783169  144.949402                 Tennis (Outdoor)       MELBOURNE
# 9085 -37.840400  144.981583                   Touch Football       MELBOURNE
# 9086 -37.825859  144.986675                   Touch Football       MELBOURNE
# 9087 -37.797812  144.924151                   Touch Football       MELBOURNE
# 9088 -37.785105  144.960662                   Touch Football       MELBOURNE
# 9089 -37.792875  144.969005                       Volleyball       MELBOURNE
# 9090 -37.796187  144.924603                       Volleyball       MELBOURNE
# 9271 -34.159700  142.127269                    Motor Cycling         MILDURA
# 9272 -34.279030  142.112539                    Motor Cycling         MILDURA
# 9287 -34.210357  142.024467                     Rugby League         MILDURA
# 9352 -37.017126  145.133140                          Cycling        MITCHELL
# 9353 -37.311472  144.518540                          Cycling  MACEDON RANGES
# 9354 -37.311472  144.518540                          Cycling  MACEDON RANGES
# 9355 -37.236452  145.220540                          Cycling     MURRINDINDI
# 9356 -37.094302  145.100900                          Cycling        MITCHELL
# 9378 -37.049540  145.178241                    Motor Cycling        MITCHELL
# 9379 -37.210168  145.082881                    Motor Cycling        MITCHELL
#
# [417 rows x 11 columns]

# %%
# check out null in SportsPlayed
data[data.SportsPlayed.isnull()]
# most of them are park and reserve
# Out:
#            Facility_ID                                       FacilityName  \
# 542        GREATE10995                          Barwon Heads Village Park
# 543        GREATE11069                                        Hamlyn Park
# 544        GREATE11115          Pioneer Reserve (Geelong baseball centre)
# 545        GREATE11152                            Waurn Ponds Tennis Club
# 1028       GLENEL11612                              Portland Angling Club
# 1359       HOBSON12971                                       Loft Reserve
# 1471        MITCHE3674                                 Vermont South Club
# 1476        ALPINE5519                    Pioneer Park Recreation Reserve
# 1617       BALLAR12511  Ballarat Regional Soccer Facility Ballarat Reg...
# 1618       BALLAR12511  Ballarat Regional Soccer Facility Ballarat Reg...
# 1619       BALLAR12511  Ballarat Regional Soccer Facility Ballarat Reg...
# 1620       BALLAR12511  Ballarat Regional Soccer Facility Ballarat Reg...
# 1621       BALLAR12511  Ballarat Regional Soccer Facility Ballarat Reg...
# 1622       BALLAR12497                                       Eastern Oval
# 1966       BASSCO11895                           Cowes Recreation Reserve
# 1967        BASSCO5565                             Inverloch Bowling Club
# 1968       BASSCO11915                       Wonthaggi Recreation Reserve
# 2416        GREATE8640                               Bendigo Bowling Club
# 2417        GREATE8671                    Garden Gully Recreation Reserve
# 2978        KNOXCI8608                              Sasses Avenue Reserve
# 3442       MACEDO10921                                Gilbert Gordon Oval
# 3443       MACEDO10960                       Ross Watt Recreation Reserve
# 3605       WANGAR11521                           Oxley Recreation Reserve
# 4022       WHITEH11041                                   Springfield Park
# 4023       WHITEH11042                                        Surrey Park
# 4174        WHITTL9537                     Lalor Reserve and Bowling club
# 4376        WYNDHA8526                        VU Wyndham Sporting Complex
# 4656       BOROON11003                              Auburn Quarry Reserve
# 4657       BOROON11010                           Burke Road South Reserve
# 5002  BULOKEBULOKE8733                    Berriwillock Recreation Reserve
# 5003  BULOKEBULOKE8733                    Berriwillock Recreation Reserve
# 5004  BULOKEBULOKE8733                    Berriwillock Recreation Reserve
# 5005  BULOKEBULOKE8754                          Donald Recreation Reserve
# 5006  BULOKEBULOKE8764                        Sea Lake Recreation Reserve
# 5235       CARDIN10996                          Catani Recreation Reserve
# 5236       CARDIN11041                                     Toomuc Reserve
# 5713        MOONEE9360                                 Cross Keys Reserve
# 5909        MORELA5544                                      Powerplay Gym
# 6743       PYRENE11080                          Amphitheatre Cricket Club
# 6789       SHEPPA11339                              Caniambo Club Grounds
# 7361        SURFCO5499                        Anderson Roadknight Reserve
# 7362       SURFCO11855                                Anglesea Bowls Club
# 7363       SURFCO11855                                Anglesea Bowls Club
# 7364       SURFCO11868                                Lorne Swimming Pool
# 7365       SURFCO11879                        Peppers The Sands Golf Club
# 7366       SURFCO11888                              Winchelsea Bowls Club
# 7781       CORANG12779                                Terang Cricket Oval
# 8017       DAREBI11803                                CH Sullivan Reserve
# 8141       EASTGI11049                               West Bairnsdale Oval
# 8311       FRANKS11060                            Peninsula Indoor Sports
# 8837       MAROON11020                                 Griff Hunt Reserve
# 9091        MELTON9051                       Brookside Recreation Reserve
# 9092        MELTON9051                       Brookside Recreation Reserve
# 9093        MELTON9079                             Mount Carberry Reserve
# 9202       MILDUR10998                         Walpeup Recreation Reserve
# 9319       MITCHE11166                                  Beveridge Reserve
#
#      StreetNo          StreetName StreetType        SuburbTown  Postcode  \
# 542       NaN             Geelong       Road      BARWON HEADS    3227.0
# 543       NaN             Calvert     Street    HAMLYN HEIGHTS    3215.0
# 544       NaN             Pioneer       Road         GROVEDALE    3216.0
# 545       NaN            Princess        Hwy       WAURN PONDS    3216.0
# 1028      NaN      Lee Breakwater       Road          PORTLAND    3305.0
# 1359     169A               Mason     Street           NEWPORT    3015.0
# 1471      NaN          Coronation     Avenue            BRIGHT    3741.0
# 1476      NaN          Coronation     Avenue            BRIGHT    3741.0
# 1617      902            Pleasant     Street             REDAN    3350.0
# 1618      902            Pleasant     Street             REDAN    3350.0
# 1619      902            Pleasant     Street             REDAN    3350.0
# 1620      902            Pleasant     Street             REDAN    3350.0
# 1621      902            Pleasant     Street             REDAN    3350.0
# 1622      NaN                Peel     Street          BALLARAT    3350.0
# 1966        9              Chapel     Street             COWES    3922.0
# 1967    23-27                 The  Esplanade         INVERLOCH    3996.0
# 1968      NaN          Korumburra       Road         WONTHAGGI    3995.0
# 2416  169-183             Barnard     Street           BENDIGO    3550.0
# 2417      NaN              Ashley     Street           BENDIGO    3550.0
# 2978      NaN              Terama       Road         BAYSWATER    3153.0
# 3442        1                Davy     Street           WOODEND    3442.0
# 3443      NaN             Station       Road      NEW GISBORNE    3438.0
# 3605      NaN  Meadow Creek-Oxley       Road             OXLEY    3678.0
# 4022      NaN             Dorking       Road        KERRRIMUIR    3130.0
# 4023      NaN              Surrey      Drive    BOX HILL SOUTH    3128.0
# 4174      NaN              Gordon     Street             LALOR    3075.0
# 4376      NaN             Hoppers       Lane          WERRIBEE    3030.0
# 4656      423              Auburn       Road     HAWTHORN EAST    3123.0
# 4657    20-28            Sinclair     Avenue          HAWTHORN    3122.0
# 5002      NaN                Golf     Street      BERRIWILLOCK    3531.0
# 5003      NaN                Golf     Street      BERRIWILLOCK    3531.0
# 5004      NaN                Golf     Street      BERRIWILLOCK    3531.0
# 5005      NaN              Borung    Highway            DONALD    3480.0
# 5006      NaN             Complex      Drive          SEA LAKE    3533.0
# 5235      NaN             Taplins       Road            CATANI    3981.0
# 5236      NaN             Princes        Hwy          PAKENHAM    3810.0
# 5713      NaN            Woodland     Street          ESSENDON    3040.0
# 5909       66              Holmes     Street         BRUNSWICK    3056.0
# 6743      NaN              School     Street      AMPHITHEATRE    3468.0
# 6789      NaN              Bridge       Road          CANIAMBO    3631.0
# 7361        6         Great Ocean       Road      AIREYS INLET    3231.0
# 7362       19             Cameron       Road          ANGLESEA    3230.0
# 7363       19             Cameron       Road          ANGLESEA    3230.0
# 7364       81            Mountjoy     Parade             LORNE    3232.0
# 7365        2               Sands  Boulevard           TORQUAY    3228.0
# 7366       51               Hesse     Street        WINCHELSEA    3241.0
# 7781      NaN                 The  Promenade            TERANG    3264.0
# 8017      NaN               Blake     Street           PRESTON    3072.0
# 8141       52            Anderson     Street        BAIRNSDALE    3875.0
# 8311      NaN              Klauer     Street           SEAFORD    3198.0
# 8837      NaN               Lyons       Road     CROYDON NORTH    3136.0
# 9091      NaN          Federation        Way  CAROLINE SPRINGS    3023.0
# 9092      NaN          Federation        Way  CAROLINE SPRINGS    3023.0
# 9093      NaN              Exford       Road      MELTON SOUTH    3338.0
# 9202      NaN            Meridian       Road           WALPEUP    3507.0
# 9319      NaN             Lithgow     Street         BEVERIDGE    3753.0
#
#        Latitude   Longitude SportsPlayed                 LGA
# 542  -38.273168  144.493427          NaN     GREATER GEELONG
# 543  -38.124723  144.331665          NaN     GREATER GEELONG
# 544  -38.197257  144.323771          NaN     GREATER GEELONG
# 545  -38.207364  144.279841          NaN     GREATER GEELONG
# 1028 -38.343574  141.607171          NaN             GLENELG
# 1359 -37.842771  144.867872          NaN         HOBSONS BAY
# 1471 -37.851683  145.180228          NaN          WHITEHORSE
# 1476 -36.737199  146.973353          NaN              ALPINE
# 1617 -37.580091  143.834217          NaN            BALLARAT
# 1618 -37.580091  143.834217          NaN            BALLARAT
# 1619 -37.580091  143.834217          NaN            BALLARAT
# 1620 -37.580091  143.834217          NaN            BALLARAT
# 1621 -37.580091  143.834217          NaN            BALLARAT
# 1622 -37.557818  143.863653          NaN            BALLARAT
# 1966 -38.451054  145.247337          NaN          BASS COAST
# 1967 -38.635349  145.732649          NaN          BASS COAST
# 1968 -38.600924  145.597243          NaN          BASS COAST
# 2416 -36.754281  144.277976          NaN     GREATER BENDIGO
# 2417 -36.754000  144.265000          NaN     GREATER BENDIGO
# 2978 -37.852554  145.256868          NaN                KNOX
# 3442 -37.351944  144.529029          NaN      MACEDON RANGES
# 3443 -37.465866  144.595836          NaN      MACEDON RANGES
# 3605 -36.470079  146.382918          NaN          WANGARATTA
# 4022 -37.808691  145.133737          NaN          WHITEHORSE
# 4023 -37.825769  145.117722          NaN          WHITEHORSE
# 4174 -37.665988  145.022917          NaN          WHITTLESEA
# 4376 -37.892629  144.702157          NaN             WYNDHAM
# 4656 -37.840687  145.042996          NaN          BOROONDARA
# 4657 -37.848670  145.050524          NaN          BOROONDARA
# 5002 -35.638964  142.989914          NaN              BULOKE
# 5003 -35.638964  142.989914          NaN              BULOKE
# 5004 -35.638964  142.989914          NaN              BULOKE
# 5005 -36.363956  142.987001          NaN              BULOKE
# 5006 -35.510326  142.856453          NaN              BULOKE
# 5235 -38.194176  145.639394          NaN            CARDINIA
# 5236 -38.066093  145.460108          NaN            CARDINIA
# 5713 -37.744580  144.929817          NaN       MOONEE VALLEY
# 5909 -37.758271  144.974742          NaN            MORELAND
# 6743 -37.184543  143.398223          NaN            PYRENEES
# 6789 -36.470908  145.630164          NaN  GREATER SHEPPARTON
# 7361 -38.456467  144.108365          NaN          SURF COAST
# 7362 -38.405953  144.191236          NaN          SURF COAST
# 7363 -38.405953  144.191236          NaN          SURF COAST
# 7364 -38.539575  143.975714          NaN          SURF COAST
# 7365 -38.314477  144.347937          NaN          SURF COAST
# 7366 -38.241572  143.987149          NaN          SURF COAST
# 7781 -38.242479  142.914266          NaN         CORANGAMITE
# 8017 -37.731075  145.037462          NaN             DAREBIN
# 8141 -37.825706  147.608127          NaN      EAST GIPPSLAND
# 8311 -38.119037  145.144000          NaN           FRANKSTON
# 8837 -37.765544  145.292259          NaN           MAROONDAH
# 9091 -37.743999  144.736611          NaN              MELTON
# 9092 -37.743999  144.736611          NaN              MELTON
# 9093 -37.706727  144.573070          NaN              MELTON
# 9202 -35.129615  142.015514          NaN             MILDURA
# 9319 -37.474705  144.980167          NaN            MITCHELL

# %%
# change list of sports
data.SportsPlayed.replace('Netball (indoor)', 'Netball (Indoor)', inplace=True)
data.SportsPlayed.replace('Tennis (indoor)', 'Tennis (Indoor)', inplace=True)
data.SportsPlayed.replace('Australian Rules football', 'Australian Rules Football', inplace=True)
data.SportsPlayed.replace('Tae Kwon Do', 'Taekwondo', inplace=True)

# %%
# what is open space
data[data.SportsPlayed == 'Open Space']
# park or reserves good for walking
# Out:
#       Facility_ID                    FacilityName StreetNo   StreetName  \
# 4265   WHITTL9558            Nick Ascenzo Reserve      NaN    Alexander
# 4266   WHITTL9515             Norris Bank Reserve      NaN      Mcleans
# 6410  MOYNES11342  Framlingham Recreation Reserve      NaN  Framlingham
#
#      StreetType   SuburbTown  Postcode   Latitude   Longitude SportsPlayed  \
# 4265     Avenue   THOMASTOWN    3074.0 -37.681034  145.026921   Open Space
# 4266       Road     BUNDOORA    3083.0 -37.694904  145.048996   Open Space
# 6410       Road  FRAMLINGHAM    3265.0 -38.255909  142.664359   Open Space
#
#              LGA
# 4265  WHITTLESEA
# 4266  WHITTLESEA
# 6410       MOYNE

# %%
# a list of sport that we may need
raw = data.SportsPlayed.unique()
sports_list = ['Netball', 'Netball (Indoor)', \
               'Rugby League', 'Rugby Union', \
               'Soccer', 'Soccer (Indoor Soccer / Futsal)', \
               'Table Tennis', 'Badminton', 'Volleyball', 'Beach Volleyball', \
               'Tennis (Indoor)', 'Tennis (Outdoor)', \
               'Gymnastics', 'Fitness / Gymnasium Workouts', 'Aerobics', \
               'Cricket (Indoor)', 'Dancing',  \
               'Australian Rules Football', \
               'AFL (Indoor)', 'Touch Football', \
               'Judo', 'Martial Arts','Karate', 'Taekwondo', \
               'Basketball', 'Baseball', 'Athletics', \
               'Open Space', 'Cycling'
              ]

# different types of football
foo = ['Australian Rules Football', 'Rugby League', 'Rugby Union', 'Touch Football']
# different types of volleyball
vol = ['Volleyball', 'Beach Volleyball']
# different types of fitness
gym = ['Gymnastics', 'Fitness / Gymnasium Workouts', 'Aerobics']
# different types of martial art
mar = ['Judo', 'Martial Arts','Karate', 'Twaekwondo']
# walking
wal = ['Open Space', 'Park / Reserve']
# cycling
cyc = ['Cycling']
# soccer
soc = ['Soccer', 'Soccer (Indoor Soccer / Futsal)']
# swimming
swi = ['Swimming']
# Tennis
ten = ['Tennis (Outdoor)','Tennis (Indoor)' ]
# other possible
other = ['Dancing', 'Athletics', 'Baseball', 'Table Tennis', 'Badminton']

raw
# must include most frequent played sports
# swimming, netball, basketball, soccer, australian rule football

# we can see that the sports list should be dealt with
# Out:
# array(['Netball', 'Netball (Indoor)', 'Polo', 'Rugby League',
#        'Rugby Union', 'Shooting Sports', 'Skating', 'Soccer',
#        'Soccer (Indoor Soccer / Futsal)', 'Softball', 'Swimming',
#        'Table Tennis', 'Tennis (Outdoor)', 'Volleyball', 'Athletics',
#        'Australian Rules Football', 'Basketball', 'BMX', 'Bocce',
#        'Boxing', 'Canoe Polo', 'Canoeing', 'Cricket', 'Cycling',
#        'Fitness / Gymnasium Workouts', 'Gaelic Football', 'Golf',
#        'Lawn Bowls', 'Martial Arts', 'Squash / Racquetball',
#        'Tennis (Indoor)', 'Underwater Hockey', 'Archery', 'Badminton',
#        'Equestrian', 'Gymnastics', 'Motor Sports', 'Sailing',
#        'Cricket (Indoor)', 'Croquet', 'Hockey', 'Dancing', 'Jet Skiing',
#        'Modern Pentathlon', 'Water Skiing', nan, 'Baseball', 'Gridiron',
#        'Karate', 'Surf Life Saving', 'Taekwondo', 'Beach Volleyball',
#        'Diving', 'Lacrosse', 'Snooker / Billiards / Pool', 'Go Karting',
#        'Polocrosse', 'Touch Football', 'Carpet Bowls', 'Rowing',
#        'AFL (Indoor)', 'Rock Climbing / Abseiling (Indoor)', 'Aerobics',
#        'Motor Cycling', 'Ten Pin Bowling', 'Disk Golf', 'Body Building',
#        'Callisthenics', 'soccer', 'Fencing', 'Rodeo', 'Open Space',
#        'Water Polo', 'Judo', 'Roller Sports - Other', 'Ice Hockey',
#        'Flying Disk', 'Inline Hockey', 'Wheelchair Sports',
#        'Orienteering', 'Team Handball', 'Power Boating'], dtype=object)

# %%
# a new dataframe
new_col=data.columns.tolist()
#new_col.append('MainSportPlayed')
print(new_col)
df = pd.DataFrame(columns=new_col)
df
# Out:
# ['Facility_ID', 'FacilityName', 'StreetNo', 'StreetName', 'StreetType', 'SuburbTown', 'Postcode', 'Latitude', 'Longitude', 'SportsPlayed', 'LGA']
# Empty DataFrame
# Columns: [Facility_ID, FacilityName, StreetNo, StreetName, StreetType, SuburbTown, Postcode, Latitude, Longitude, SportsPlayed, LGA]
# Index: []

# %%
# new dataframe selected sports type
# as long as there is park/reserve in name
for i in range(data.shape[0]):
    
    names = data.iloc[i,:].FacilityName
    sports = data.iloc[i,:].SportsPlayed
    # sports
    # this may deal with null values
    if 'park' in names or 'reserve' in names:
        new_row = {}
        new_row = {'Facility_ID': data.iloc[i,:].Facility_ID,
                   'FacilityName': data.iloc[i,:].FacilityName,
                   'StreetNo': data.iloc[i,:].StreetNo,
                   'StreetType': data.iloc[i,:].StreetType,
                   'SuburbTown': data.iloc[i,:].SuburbTown,
                   'Latitude': data.iloc[i,:].Latitude,
                   'Longitude': data.iloc[i,:].Longitude,
                   'SportsPlayed': 'Park / Reserve',
                   #'MainSportsPlayed': 'Walking',
                   'LGA': data.iloc[i,:].LGA
            
        }
        #print(names, data.iloc[i,:].SportsPlayed)
        df = df.append(new_row, ignore_index=True)
        
    if sports in sports_list:
        df = df.append(data.iloc[i,:], ignore_index=True)

# %%
df.shape
# Out:
# (5540, 11)

# %%
df.head(10)
# Out:
#    Facility_ID                      FacilityName StreetNo StreetName  \
# 0   WYNDHA8530  Werribee Sports & Fitness Centre      NaN     Ballan
# 1  WYNDHA11288             Hoppers Indoor Sportz      NaN     Graham
# 2   WYNDHA8521           Riverside Indoor Sports       13  Riverside
# 3   WYNDHA5496           Clearwood Drive Reserve      NaN  Clearwood
# 4  WYNDHA11000              Haines Drive Reserve      NaN     Haines
# 5  WYNDHA11000              Haines Drive Reserve      NaN     Haines
# 6   WYNDHA8514                  Mossfiel Reserve      NaN     Heaths
# 7  WYNDHA10998              Forsyth Road Reserve      NaN    Forsyth
# 8  WYNDHA10998              Forsyth Road Reserve      NaN    Forsyth
# 9   WYNDHA8502                       Galvin Park      NaN      Shaws
#
#   StreetType        SuburbTown  Postcode   Latitude   Longitude  \
# 0       Road          WERRIBEE    3030.0 -37.898601  144.640316
# 1      Court  HOPPERS CROSSING    3029.0 -37.872000  144.727500
# 2     Avenue          WERRIBEE    3030.0 -37.913492  144.659074
# 3      Drive         TRUGANINA       NaN -37.840037  144.717830
# 4       Road      WYNDHAM VALE    3024.0 -37.897069  144.609389
# 5       Road      WYNDHAM VALE    3024.0 -37.897069  144.609389
# 6       Road  HOPPERS CROSSING    3029.0 -37.877437  144.692478
# 7       Road         TRUGANINA    3029.0 -37.860804  144.729419
# 8       Road         TRUGANINA    3029.0 -37.860804  144.729419
# 9       Road          WERRIBEE    3030.0 -37.887060  144.650409
#
#        SportsPlayed      LGA
# 0           Netball  WYNDHAM
# 1  Netball (Indoor)  WYNDHAM
# 2  Netball (Indoor)  WYNDHAM
# 3      Rugby League  WYNDHAM
# 4      Rugby League  WYNDHAM
# 5       Rugby Union  WYNDHAM
# 6       Rugby Union  WYNDHAM
# 7            Soccer  WYNDHAM
# 8            Soccer  WYNDHAM
# 9            Soccer  WYNDHAM

# %%
df[df.Postcode.isnull()]
# Out:
#       Facility_ID                                   FacilityName StreetNo  \
# 3      WYNDHA5496                        Clearwood Drive Reserve      NaN
# 43    YARRAC11029                  Collingwood Secondary College      NaN
# 44    YARRAC11032                      Fitzroy Secondary  School      NaN
# 45    YARRAC11028                        Melbourne Girls College      NaN
# 46    YARRAC11030                  Princes Hill Seconary College      NaN
# 47     YARRAC5306                                  Kew Boulevard      NaN
# 48     YARRAC5282                           Yarra Boulevard Loop      NaN
# 80    YARRAC11024  Melbourne Aboriginal Sport and Recreation Gym      NaN
# 86    YARRAC11023                           Richmond Boxing Club      NaN
# 93    YARRAC11022                            Stanton Street Hall      NaN
# 111   YARRAC11028                        Melbourne Girls College      NaN
# 124   YARRAC11021                               Mc Cutcheon Oval      NaN
# 127   YARRAC11029                  Collingwood Secondary College      NaN
# 128   YARRAC11030                  Princes Hill Seconary College      NaN
# 129   YARRAC11031                   Princess Hill Primary School      NaN
# 135   YARRAC11029                  Collingwood Secondary College      NaN
# 171    YARRAR5421                               Lysterfield Park      NaN
# 175   YARRAR11429                             Fit Chirnside park      282
# 322   GREATE11066         Goldsworthy reserve Athletics facility      NaN
# 331   GREATE11017                  Collendina Recreation reserve      NaN
# 336    GEELON5453                                 Estuary Estate  293-319
# 339   GREATE11070                           Harold Hurst reserve      NaN
# 347   GREATE11092            Leopold Memorial Recreation reserve      NaN
# 354   GREATE11120               Portarlington Recreation reserve      NaN
# 360   GREATE11128                             Shell Road reserve      NaN
# 362   GREATE11130                           South Barwon reserve      NaN
# 367   GREATE11156                               Windmill reserve      NaN
# 381   GREATE11130                           South Barwon reserve      NaN
# 382   GREATE11017                  Collendina Recreation reserve      NaN
# 383   GREATE11070                           Harold Hurst reserve      NaN
# ...           ...                                            ...      ...
# 5304  MELBOU11019                              Newmarket Reserve      NaN
# 5305  MELBOU11020               North Melbourne Community Centre       53
# 5306  MELBOU11023                                   Princes Park      NaN
# 5307  MELBOU11026                                     Royal Park      NaN
# 5308  MELBOU11027                  State Netball & Hockey Centre      NaN
# 5309  MELBOU10988                 Carlton Baths Community Centre      248
# 5310  MELBOU11008         Kensington Community Recreation Centre      NaN
# 5311  MELBOU11020               North Melbourne Community Centre       53
# 5312  MELBOU11022              North Melbourne Recreation Centre      206
# 5313  MELBOU10990                    Carlton Gardens Tennis Club       11
# 5314  MELBOU10994                                   Fawkner Park      NaN
# 5315  MELBOU11000                              Flagstaff Gardens      NaN
# 5316  MELBOU11007                   Kensington Banks Tennis Club      NaN
# 5317  MELBOU11017                                 Melbourne Park      NaN
# 5318  MELBOU11023                                   Princes Park      NaN
# 5319  MELBOU11023                                   Princes Park      NaN
# 5320  MELBOU11026                                     Royal Park      NaN
# 5321  MELBOU11026                                     Royal Park      NaN
# 5322  MELBOU10994                                   Fawkner Park      NaN
# 5323  MELBOU11004                                 Goschs Paddock      NaN
# 5324  MELBOU11006                                JJ Holland Park      NaN
# 5325  MELBOU11023                                   Princes Park      NaN
# 5326  MELBOU10988                 Carlton Baths Community Centre      248
# 5327  MELBOU11008         Kensington Community Recreation Centre      NaN
# 5441   MILDUR5495                          Nichols Point Reserve      NaN
# 5483   MITCHE5377                                     Anvel Loop       82
# 5484   MITCHE5299                                Carlsrushe West      NaN
# 5485   MITCHE5300                              Carlsrushe West 2      NaN
# 5486   MITCHE5305                           Strath Creek Circuit      NaN
# 5487   MITCHE5378                               Talarook Circuit      NaN
#
#                   StreetName    StreetType        SuburbTown  Postcode  \
# 3                  Clearwood         Drive         TRUGANINA       NaN
# 43               Mc Cutcheon           Way       COLLINGWOOD       NaN
# 44                  Falconer        Street           FITZROY       NaN
# 45                     Yarra     Boulevard           BURNLEY       NaN
# 46                    Arnold        Strret      PRINCES HILL       NaN
# 47                       Kew     Boulevard               KEW       NaN
# 48                     Yarra     Boulevard          RICHMOND       NaN
# 80                  Gertrude        Street           FITZROY       NaN
# 86                  Gleadell        Street          RICHMOND       NaN
# 93                   Stanton        Street       COLLINGWOOD       NaN
# 111                    Yarra     Boulevard           BURNLEY       NaN
# 124               Yarra Bend          Road         FAIRFIELD       NaN
# 127              Mc Cutcheon           Way       COLLINGWOOD       NaN
# 128                   Arnold        Strret      PRINCES HILL       NaN
# 129                   Pigdon        Street      PRINCES HILL       NaN
# 135              Mc Cutcheon           Way       COLLINGWOOD       NaN
# 171                      NaN           NaN               NaN       NaN
# 175                      NaN           Hwy    CHIRNSIDE PARK       NaN
# 322                      NaN          Road             CORIO       NaN
# 331                      NaN         Close       OCEAN GROVE       NaN
# 336                 Melaluka          Road           LEOPOLD       NaN
# 339                      NaN        Street        HERNE HILL       NaN
# 347                      NaN          Road           LEOPOLD       NaN
# 354                      NaN        Street     PORTARLINGTON       NaN
# 360                      NaN          Road       OCEAN GROVE       NaN
# 362                      NaN          Road           BELMONT       NaN
# 367                      NaN         Drive           NEWTOWN       NaN
# 381                      NaN          Road           BELMONT       NaN
# 382                      NaN         Close       OCEAN GROVE       NaN
# 383                      NaN        Street        HERNE HILL       NaN
# ...                      ...           ...               ...       ...
# 5304              Smithfield          Road        FLEMINGTON       NaN
# 5305                  Buncle        Street   NORTH MELBOURNE       NaN
# 5306                   Royal        Parade         PARKVILLE       NaN
# 5307               Macarthur          Road         PARKVILLE       NaN
# 5308                   Brens         Drive         PARKVILLE       NaN
# 5309               Rathdowne        Street           CARLTON       NaN
# 5310                  Altona        Street        KENSINGTON       NaN
# 5311                  Buncle        Street   NORTH MELBOURNE       NaN
# 5312                   Arden        Street   NORTH MELBOURNE       NaN
# 5313               Nicholson        Street         MELBOURNE       NaN
# 5314                  Pasley  Street North       SOUTH YARRA       NaN
# 5315                 William        Street         MELBOURNE       NaN
# 5316                Speakman        Street        KENSINGTON       NaN
# 5317                 Olympic     Boulevard         MELBOURNE       NaN
# 5318                   Royal        Parade         PARKVILLE       NaN
# 5319                   Royal        Parade         PARKVILLE       NaN
# 5320               Macarthur          Road         PARKVILLE       NaN
# 5321               Macarthur          Road         PARKVILLE       NaN
# 5322                  Pasley  Street North       SOUTH YARRA       NaN
# 5323                    Punt          Road          RICHMOND       NaN
# 5324              Kensington          Road  SOUTH KENSINGTON       NaN
# 5325                   Royal        Parade         PARKVILLE       NaN
# 5326               Rathdowne        Street           CARLTON       NaN
# 5327                  Altona        Street        KENSINGTON       NaN
# 5441                     NaN           NaN               NaN       NaN
# 5483                   Emily        Street           SEYMOUR       NaN
# 5484   Broadford - Glenaroua          Road        CARLSRUSHE       NaN
# 5485      Carlsrushe Central          Road        CARLSRUSHE       NaN
# 5486  Broadford - Flowerdale          Road      STRATH CREEK       NaN
# 5487                 Trawool           NaN          TALAROOK       NaN
#
#        Latitude   Longitude                     SportsPlayed              LGA
# 3    -37.840037  144.717830                     Rugby League          WYNDHAM
# 43   -37.803256  144.989030                       Basketball            YARRA
# 44   -37.800909  144.979157                       Basketball            YARRA
# 45   -37.829690  145.012699                       Basketball            YARRA
# 46   -37.781818  144.966587                       Basketball            YARRA
# 47   -37.806529  145.010120                          Cycling       BOROONDARA
# 48   -37.793700  145.015130                          Cycling       BOROONDARA
# 80   -37.805467  144.974449     Fitness / Gymnasium Workouts            YARRA
# 86   -37.818380  145.001525     Fitness / Gymnasium Workouts            YARRA
# 93   -37.801956  144.988164     Fitness / Gymnasium Workouts            YARRA
# 111  -37.829690  145.012699                          Netball            YARRA
# 124  -37.799975  145.008575                           Soccer            YARRA
# 127  -37.803256  144.989030  Soccer (Indoor Soccer / Futsal)            YARRA
# 128  -37.781818  144.966587  Soccer (Indoor Soccer / Futsal)            YARRA
# 129  -37.780992  144.962781  Soccer (Indoor Soccer / Futsal)        MELBOURNE
# 135  -37.803256  144.989030                       Volleyball            YARRA
# 171  -37.970049  145.301056                          Cycling            CASEY
# 175  -37.766357  145.305667                   Park / Reserve     YARRA RANGES
# 322  -38.078959  144.353257                   Park / Reserve  GREATER GEELONG
# 331  -38.267278  144.548822                   Park / Reserve  GREATER GEELONG
# 336  -38.202327  144.453856        Australian Rules Football  GREATER GEELONG
# 339  -38.131441  144.327187                   Park / Reserve  GREATER GEELONG
# 347  -38.184416  144.456859                   Park / Reserve  GREATER GEELONG
# 354  -38.113612  144.643431                   Park / Reserve  GREATER GEELONG
# 360  -38.259389  144.537787                   Park / Reserve  GREATER GEELONG
# 362  -38.182921  144.355990                   Park / Reserve  GREATER GEELONG
# 367  -38.152708  144.324953                   Park / Reserve  GREATER GEELONG
# 381  -38.182921  144.355990                   Park / Reserve  GREATER GEELONG
# 382  -38.267278  144.548822                   Park / Reserve  GREATER GEELONG
# 383  -38.131441  144.327187                   Park / Reserve  GREATER GEELONG
# ...         ...         ...                              ...              ...
# 5304 -37.788141  144.923465                           Soccer        MELBOURNE
# 5305 -37.793231  144.939922                           Soccer        MELBOURNE
# 5306 -37.785105  144.960662                           Soccer        MELBOURNE
# 5307 -37.783169  144.949402                           Soccer        MELBOURNE
# 5308 -37.783169  144.949402                           Soccer        MELBOURNE
# 5309 -37.792875  144.969005  Soccer (Indoor Soccer / Futsal)        MELBOURNE
# 5310 -37.796187  144.924603  Soccer (Indoor Soccer / Futsal)        MELBOURNE
# 5311 -37.793231  144.939922  Soccer (Indoor Soccer / Futsal)        MELBOURNE
# 5312 -37.799291  144.941973  Soccer (Indoor Soccer / Futsal)        MELBOURNE
# 5313 -37.802325  144.972860                 Tennis (Outdoor)        MELBOURNE
# 5314 -37.840400  144.981583                 Tennis (Outdoor)        MELBOURNE
# 5315 -37.809912  144.954430                 Tennis (Outdoor)        MELBOURNE
# 5316 -37.794534  144.915836                 Tennis (Outdoor)        MELBOURNE
# 5317 -37.821437  144.979104                 Tennis (Outdoor)        MELBOURNE
# 5318 -37.785105  144.960662                 Tennis (Outdoor)        MELBOURNE
# 5319 -37.785105  144.960662                 Tennis (Outdoor)        MELBOURNE
# 5320 -37.783169  144.949402                 Tennis (Outdoor)        MELBOURNE
# 5321 -37.783169  144.949402                 Tennis (Outdoor)        MELBOURNE
# 5322 -37.840400  144.981583                   Touch Football        MELBOURNE
# 5323 -37.825859  144.986675                   Touch Football        MELBOURNE
# 5324 -37.797812  144.924151                   Touch Football        MELBOURNE
# 5325 -37.785105  144.960662                   Touch Football        MELBOURNE
# 5326 -37.792875  144.969005                       Volleyball        MELBOURNE
# 5327 -37.796187  144.924603                       Volleyball        MELBOURNE
# 5441 -34.210357  142.024467                     Rugby League          MILDURA
# 5483 -37.017126  145.133140                          Cycling         MITCHELL
# 5484 -37.311472  144.518540                          Cycling   MACEDON RANGES
# 5485 -37.311472  144.518540                          Cycling   MACEDON RANGES
# 5486 -37.236452  145.220540                          Cycling      MURRINDINDI
# 5487 -37.094302  145.100900                          Cycling         MITCHELL
#
# [439 rows x 11 columns]

# %%
df.SportsPlayed.unique().tolist()
# Out:
# ['Netball',
#  'Netball (Indoor)',
#  'Rugby League',
#  'Rugby Union',
#  'Soccer',
#  'Soccer (Indoor Soccer / Futsal)',
#  'Table Tennis',
#  'Tennis (Outdoor)',
#  'Volleyball',
#  'Athletics',
#  'Australian Rules Football',
#  'Basketball',
#  'Cycling',
#  'Fitness / Gymnasium Workouts',
#  'Martial Arts',
#  'Tennis (Indoor)',
#  'Badminton',
#  'Park / Reserve',
#  'Gymnastics',
#  'Cricket (Indoor)',
#  'Dancing',
#  'Baseball',
#  'Karate',
#  'Taekwondo',
#  'Beach Volleyball',
#  'Touch Football',
#  'AFL (Indoor)',
#  'Aerobics',
#  'Open Space',
#  'Judo']

# %%
df1 = df.copy()
df1.head()
# Out:
#    Facility_ID                      FacilityName StreetNo StreetName  \
# 0   WYNDHA8530  Werribee Sports & Fitness Centre      NaN     Ballan
# 1  WYNDHA11288             Hoppers Indoor Sportz      NaN     Graham
# 2   WYNDHA8521           Riverside Indoor Sports       13  Riverside
# 3   WYNDHA5496           Clearwood Drive Reserve      NaN  Clearwood
# 4  WYNDHA11000              Haines Drive Reserve      NaN     Haines
#
#   StreetType        SuburbTown  Postcode   Latitude   Longitude  \
# 0       Road          WERRIBEE    3030.0 -37.898601  144.640316
# 1      Court  HOPPERS CROSSING    3029.0 -37.872000  144.727500
# 2     Avenue          WERRIBEE    3030.0 -37.913492  144.659074
# 3      Drive         TRUGANINA       NaN -37.840037  144.717830
# 4       Road      WYNDHAM VALE    3024.0 -37.897069  144.609389
#
#        SportsPlayed      LGA
# 0           Netball  WYNDHAM
# 1  Netball (Indoor)  WYNDHAM
# 2  Netball (Indoor)  WYNDHAM
# 3      Rugby League  WYNDHAM
# 4      Rugby League  WYNDHAM

# %%
# read in API
with open('google_map_api_key.txt') as f:
    api_key = f.readline()
    f.close
    
#api_key

# %%
df2 = df[df.Postcode.isnull()]

# %%
df2.shape
# Out:
# (439, 11)

# %%
df2[df2.Postcode.isnull()]
# Out:
#       Facility_ID                                   FacilityName StreetNo  \
# 3      WYNDHA5496                        Clearwood Drive Reserve      NaN
# 43    YARRAC11029                  Collingwood Secondary College      NaN
# 44    YARRAC11032                      Fitzroy Secondary  School      NaN
# 45    YARRAC11028                        Melbourne Girls College      NaN
# 46    YARRAC11030                  Princes Hill Seconary College      NaN
# 47     YARRAC5306                                  Kew Boulevard      NaN
# 48     YARRAC5282                           Yarra Boulevard Loop      NaN
# 80    YARRAC11024  Melbourne Aboriginal Sport and Recreation Gym      NaN
# 86    YARRAC11023                           Richmond Boxing Club      NaN
# 93    YARRAC11022                            Stanton Street Hall      NaN
# 111   YARRAC11028                        Melbourne Girls College      NaN
# 124   YARRAC11021                               Mc Cutcheon Oval      NaN
# 127   YARRAC11029                  Collingwood Secondary College      NaN
# 128   YARRAC11030                  Princes Hill Seconary College      NaN
# 129   YARRAC11031                   Princess Hill Primary School      NaN
# 135   YARRAC11029                  Collingwood Secondary College      NaN
# 171    YARRAR5421                               Lysterfield Park      NaN
# 175   YARRAR11429                             Fit Chirnside park      282
# 322   GREATE11066         Goldsworthy reserve Athletics facility      NaN
# 331   GREATE11017                  Collendina Recreation reserve      NaN
# 336    GEELON5453                                 Estuary Estate  293-319
# 339   GREATE11070                           Harold Hurst reserve      NaN
# 347   GREATE11092            Leopold Memorial Recreation reserve      NaN
# 354   GREATE11120               Portarlington Recreation reserve      NaN
# 360   GREATE11128                             Shell Road reserve      NaN
# 362   GREATE11130                           South Barwon reserve      NaN
# 367   GREATE11156                               Windmill reserve      NaN
# 381   GREATE11130                           South Barwon reserve      NaN
# 382   GREATE11017                  Collendina Recreation reserve      NaN
# 383   GREATE11070                           Harold Hurst reserve      NaN
# ...           ...                                            ...      ...
# 5304  MELBOU11019                              Newmarket Reserve      NaN
# 5305  MELBOU11020               North Melbourne Community Centre       53
# 5306  MELBOU11023                                   Princes Park      NaN
# 5307  MELBOU11026                                     Royal Park      NaN
# 5308  MELBOU11027                  State Netball & Hockey Centre      NaN
# 5309  MELBOU10988                 Carlton Baths Community Centre      248
# 5310  MELBOU11008         Kensington Community Recreation Centre      NaN
# 5311  MELBOU11020               North Melbourne Community Centre       53
# 5312  MELBOU11022              North Melbourne Recreation Centre      206
# 5313  MELBOU10990                    Carlton Gardens Tennis Club       11
# 5314  MELBOU10994                                   Fawkner Park      NaN
# 5315  MELBOU11000                              Flagstaff Gardens      NaN
# 5316  MELBOU11007                   Kensington Banks Tennis Club      NaN
# 5317  MELBOU11017                                 Melbourne Park      NaN
# 5318  MELBOU11023                                   Princes Park      NaN
# 5319  MELBOU11023                                   Princes Park      NaN
# 5320  MELBOU11026                                     Royal Park      NaN
# 5321  MELBOU11026                                     Royal Park      NaN
# 5322  MELBOU10994                                   Fawkner Park      NaN
# 5323  MELBOU11004                                 Goschs Paddock      NaN
# 5324  MELBOU11006                                JJ Holland Park      NaN
# 5325  MELBOU11023                                   Princes Park      NaN
# 5326  MELBOU10988                 Carlton Baths Community Centre      248
# 5327  MELBOU11008         Kensington Community Recreation Centre      NaN
# 5441   MILDUR5495                          Nichols Point Reserve      NaN
# 5483   MITCHE5377                                     Anvel Loop       82
# 5484   MITCHE5299                                Carlsrushe West      NaN
# 5485   MITCHE5300                              Carlsrushe West 2      NaN
# 5486   MITCHE5305                           Strath Creek Circuit      NaN
# 5487   MITCHE5378                               Talarook Circuit      NaN
#
#                   StreetName    StreetType        SuburbTown  Postcode  \
# 3                  Clearwood         Drive         TRUGANINA       NaN
# 43               Mc Cutcheon           Way       COLLINGWOOD       NaN
# 44                  Falconer        Street           FITZROY       NaN
# 45                     Yarra     Boulevard           BURNLEY       NaN
# 46                    Arnold        Strret      PRINCES HILL       NaN
# 47                       Kew     Boulevard               KEW       NaN
# 48                     Yarra     Boulevard          RICHMOND       NaN
# 80                  Gertrude        Street           FITZROY       NaN
# 86                  Gleadell        Street          RICHMOND       NaN
# 93                   Stanton        Street       COLLINGWOOD       NaN
# 111                    Yarra     Boulevard           BURNLEY       NaN
# 124               Yarra Bend          Road         FAIRFIELD       NaN
# 127              Mc Cutcheon           Way       COLLINGWOOD       NaN
# 128                   Arnold        Strret      PRINCES HILL       NaN
# 129                   Pigdon        Street      PRINCES HILL       NaN
# 135              Mc Cutcheon           Way       COLLINGWOOD       NaN
# 171                      NaN           NaN               NaN       NaN
# 175                      NaN           Hwy    CHIRNSIDE PARK       NaN
# 322                      NaN          Road             CORIO       NaN
# 331                      NaN         Close       OCEAN GROVE       NaN
# 336                 Melaluka          Road           LEOPOLD       NaN
# 339                      NaN        Street        HERNE HILL       NaN
# 347                      NaN          Road           LEOPOLD       NaN
# 354                      NaN        Street     PORTARLINGTON       NaN
# 360                      NaN          Road       OCEAN GROVE       NaN
# 362                      NaN          Road           BELMONT       NaN
# 367                      NaN         Drive           NEWTOWN       NaN
# 381                      NaN          Road           BELMONT       NaN
# 382                      NaN         Close       OCEAN GROVE       NaN
# 383                      NaN        Street        HERNE HILL       NaN
# ...                      ...           ...               ...       ...
# 5304              Smithfield          Road        FLEMINGTON       NaN
# 5305                  Buncle        Street   NORTH MELBOURNE       NaN
# 5306                   Royal        Parade         PARKVILLE       NaN
# 5307               Macarthur          Road         PARKVILLE       NaN
# 5308                   Brens         Drive         PARKVILLE       NaN
# 5309               Rathdowne        Street           CARLTON       NaN
# 5310                  Altona        Street        KENSINGTON       NaN
# 5311                  Buncle        Street   NORTH MELBOURNE       NaN
# 5312                   Arden        Street   NORTH MELBOURNE       NaN
# 5313               Nicholson        Street         MELBOURNE       NaN
# 5314                  Pasley  Street North       SOUTH YARRA       NaN
# 5315                 William        Street         MELBOURNE       NaN
# 5316                Speakman        Street        KENSINGTON       NaN
# 5317                 Olympic     Boulevard         MELBOURNE       NaN
# 5318                   Royal        Parade         PARKVILLE       NaN
# 5319                   Royal        Parade         PARKVILLE       NaN
# 5320               Macarthur          Road         PARKVILLE       NaN
# 5321               Macarthur          Road         PARKVILLE       NaN
# 5322                  Pasley  Street North       SOUTH YARRA       NaN
# 5323                    Punt          Road          RICHMOND       NaN
# 5324              Kensington          Road  SOUTH KENSINGTON       NaN
# 5325                   Royal        Parade         PARKVILLE       NaN
# 5326               Rathdowne        Street           CARLTON       NaN
# 5327                  Altona        Street        KENSINGTON       NaN
# 5441                     NaN           NaN               NaN       NaN
# 5483                   Emily        Street           SEYMOUR       NaN
# 5484   Broadford - Glenaroua          Road        CARLSRUSHE       NaN
# 5485      Carlsrushe Central          Road        CARLSRUSHE       NaN
# 5486  Broadford - Flowerdale          Road      STRATH CREEK       NaN
# 5487                 Trawool           NaN          TALAROOK       NaN
#
#        Latitude   Longitude                     SportsPlayed              LGA
# 3    -37.840037  144.717830                     Rugby League          WYNDHAM
# 43   -37.803256  144.989030                       Basketball            YARRA
# 44   -37.800909  144.979157                       Basketball            YARRA
# 45   -37.829690  145.012699                       Basketball            YARRA
# 46   -37.781818  144.966587                       Basketball            YARRA
# 47   -37.806529  145.010120                          Cycling       BOROONDARA
# 48   -37.793700  145.015130                          Cycling       BOROONDARA
# 80   -37.805467  144.974449     Fitness / Gymnasium Workouts            YARRA
# 86   -37.818380  145.001525     Fitness / Gymnasium Workouts            YARRA
# 93   -37.801956  144.988164     Fitness / Gymnasium Workouts            YARRA
# 111  -37.829690  145.012699                          Netball            YARRA
# 124  -37.799975  145.008575                           Soccer            YARRA
# 127  -37.803256  144.989030  Soccer (Indoor Soccer / Futsal)            YARRA
# 128  -37.781818  144.966587  Soccer (Indoor Soccer / Futsal)            YARRA
# 129  -37.780992  144.962781  Soccer (Indoor Soccer / Futsal)        MELBOURNE
# 135  -37.803256  144.989030                       Volleyball            YARRA
# 171  -37.970049  145.301056                          Cycling            CASEY
# 175  -37.766357  145.305667                   Park / Reserve     YARRA RANGES
# 322  -38.078959  144.353257                   Park / Reserve  GREATER GEELONG
# 331  -38.267278  144.548822                   Park / Reserve  GREATER GEELONG
# 336  -38.202327  144.453856        Australian Rules Football  GREATER GEELONG
# 339  -38.131441  144.327187                   Park / Reserve  GREATER GEELONG
# 347  -38.184416  144.456859                   Park / Reserve  GREATER GEELONG
# 354  -38.113612  144.643431                   Park / Reserve  GREATER GEELONG
# 360  -38.259389  144.537787                   Park / Reserve  GREATER GEELONG
# 362  -38.182921  144.355990                   Park / Reserve  GREATER GEELONG
# 367  -38.152708  144.324953                   Park / Reserve  GREATER GEELONG
# 381  -38.182921  144.355990                   Park / Reserve  GREATER GEELONG
# 382  -38.267278  144.548822                   Park / Reserve  GREATER GEELONG
# 383  -38.131441  144.327187                   Park / Reserve  GREATER GEELONG
# ...         ...         ...                              ...              ...
# 5304 -37.788141  144.923465                           Soccer        MELBOURNE
# 5305 -37.793231  144.939922                           Soccer        MELBOURNE
# 5306 -37.785105  144.960662                           Soccer        MELBOURNE
# 5307 -37.783169  144.949402                           Soccer        MELBOURNE
# 5308 -37.783169  144.949402                           Soccer        MELBOURNE
# 5309 -37.792875  144.969005  Soccer (Indoor Soccer / Futsal)        MELBOURNE
# 5310 -37.796187  144.924603  Soccer (Indoor Soccer / Futsal)        MELBOURNE
# 5311 -37.793231  144.939922  Soccer (Indoor Soccer / Futsal)        MELBOURNE
# 5312 -37.799291  144.941973  Soccer (Indoor Soccer / Futsal)        MELBOURNE
# 5313 -37.802325  144.972860                 Tennis (Outdoor)        MELBOURNE
# 5314 -37.840400  144.981583                 Tennis (Outdoor)        MELBOURNE
# 5315 -37.809912  144.954430                 Tennis (Outdoor)        MELBOURNE
# 5316 -37.794534  144.915836                 Tennis (Outdoor)        MELBOURNE
# 5317 -37.821437  144.979104                 Tennis (Outdoor)        MELBOURNE
# 5318 -37.785105  144.960662                 Tennis (Outdoor)        MELBOURNE
# 5319 -37.785105  144.960662                 Tennis (Outdoor)        MELBOURNE
# 5320 -37.783169  144.949402                 Tennis (Outdoor)        MELBOURNE
# 5321 -37.783169  144.949402                 Tennis (Outdoor)        MELBOURNE
# 5322 -37.840400  144.981583                   Touch Football        MELBOURNE
# 5323 -37.825859  144.986675                   Touch Football        MELBOURNE
# 5324 -37.797812  144.924151                   Touch Football        MELBOURNE
# 5325 -37.785105  144.960662                   Touch Football        MELBOURNE
# 5326 -37.792875  144.969005                       Volleyball        MELBOURNE
# 5327 -37.796187  144.924603                       Volleyball        MELBOURNE
# 5441 -34.210357  142.024467                     Rugby League          MILDURA
# 5483 -37.017126  145.133140                          Cycling         MITCHELL
# 5484 -37.311472  144.518540                          Cycling   MACEDON RANGES
# 5485 -37.311472  144.518540                          Cycling   MACEDON RANGES
# 5486 -37.236452  145.220540                          Cycling      MURRINDINDI
# 5487 -37.094302  145.100900                          Cycling         MITCHELL
#
# [439 rows x 11 columns]

# %%
# reset the indexes
df2.reset_index(inplace=True, drop=True)
df2
# Out:
#      Facility_ID                                   FacilityName StreetNo  \
# 0     WYNDHA5496                        Clearwood Drive Reserve      NaN
# 1    YARRAC11029                  Collingwood Secondary College      NaN
# 2    YARRAC11032                      Fitzroy Secondary  School      NaN
# 3    YARRAC11028                        Melbourne Girls College      NaN
# 4    YARRAC11030                  Princes Hill Seconary College      NaN
# 5     YARRAC5306                                  Kew Boulevard      NaN
# 6     YARRAC5282                           Yarra Boulevard Loop      NaN
# 7    YARRAC11024  Melbourne Aboriginal Sport and Recreation Gym      NaN
# 8    YARRAC11023                           Richmond Boxing Club      NaN
# 9    YARRAC11022                            Stanton Street Hall      NaN
# 10   YARRAC11028                        Melbourne Girls College      NaN
# 11   YARRAC11021                               Mc Cutcheon Oval      NaN
# 12   YARRAC11029                  Collingwood Secondary College      NaN
# 13   YARRAC11030                  Princes Hill Seconary College      NaN
# 14   YARRAC11031                   Princess Hill Primary School      NaN
# 15   YARRAC11029                  Collingwood Secondary College      NaN
# 16    YARRAR5421                               Lysterfield Park      NaN
# 17   YARRAR11429                             Fit Chirnside park      282
# 18   GREATE11066         Goldsworthy reserve Athletics facility      NaN
# 19   GREATE11017                  Collendina Recreation reserve      NaN
# 20    GEELON5453                                 Estuary Estate  293-319
# 21   GREATE11070                           Harold Hurst reserve      NaN
# 22   GREATE11092            Leopold Memorial Recreation reserve      NaN
# 23   GREATE11120               Portarlington Recreation reserve      NaN
# 24   GREATE11128                             Shell Road reserve      NaN
# 25   GREATE11130                           South Barwon reserve      NaN
# 26   GREATE11156                               Windmill reserve      NaN
# 27   GREATE11130                           South Barwon reserve      NaN
# 28   GREATE11017                  Collendina Recreation reserve      NaN
# 29   GREATE11070                           Harold Hurst reserve      NaN
# ..           ...                                            ...      ...
# 409  MELBOU11019                              Newmarket Reserve      NaN
# 410  MELBOU11020               North Melbourne Community Centre       53
# 411  MELBOU11023                                   Princes Park      NaN
# 412  MELBOU11026                                     Royal Park      NaN
# 413  MELBOU11027                  State Netball & Hockey Centre      NaN
# 414  MELBOU10988                 Carlton Baths Community Centre      248
# 415  MELBOU11008         Kensington Community Recreation Centre      NaN
# 416  MELBOU11020               North Melbourne Community Centre       53
# 417  MELBOU11022              North Melbourne Recreation Centre      206
# 418  MELBOU10990                    Carlton Gardens Tennis Club       11
# 419  MELBOU10994                                   Fawkner Park      NaN
# 420  MELBOU11000                              Flagstaff Gardens      NaN
# 421  MELBOU11007                   Kensington Banks Tennis Club      NaN
# 422  MELBOU11017                                 Melbourne Park      NaN
# 423  MELBOU11023                                   Princes Park      NaN
# 424  MELBOU11023                                   Princes Park      NaN
# 425  MELBOU11026                                     Royal Park      NaN
# 426  MELBOU11026                                     Royal Park      NaN
# 427  MELBOU10994                                   Fawkner Park      NaN
# 428  MELBOU11004                                 Goschs Paddock      NaN
# 429  MELBOU11006                                JJ Holland Park      NaN
# 430  MELBOU11023                                   Princes Park      NaN
# 431  MELBOU10988                 Carlton Baths Community Centre      248
# 432  MELBOU11008         Kensington Community Recreation Centre      NaN
# 433   MILDUR5495                          Nichols Point Reserve      NaN
# 434   MITCHE5377                                     Anvel Loop       82
# 435   MITCHE5299                                Carlsrushe West      NaN
# 436   MITCHE5300                              Carlsrushe West 2      NaN
# 437   MITCHE5305                           Strath Creek Circuit      NaN
# 438   MITCHE5378                               Talarook Circuit      NaN
#
#                  StreetName    StreetType        SuburbTown  Postcode  \
# 0                 Clearwood         Drive         TRUGANINA       NaN
# 1               Mc Cutcheon           Way       COLLINGWOOD       NaN
# 2                  Falconer        Street           FITZROY       NaN
# 3                     Yarra     Boulevard           BURNLEY       NaN
# 4                    Arnold        Strret      PRINCES HILL       NaN
# 5                       Kew     Boulevard               KEW       NaN
# 6                     Yarra     Boulevard          RICHMOND       NaN
# 7                  Gertrude        Street           FITZROY       NaN
# 8                  Gleadell        Street          RICHMOND       NaN
# 9                   Stanton        Street       COLLINGWOOD       NaN
# 10                    Yarra     Boulevard           BURNLEY       NaN
# 11               Yarra Bend          Road         FAIRFIELD       NaN
# 12              Mc Cutcheon           Way       COLLINGWOOD       NaN
# 13                   Arnold        Strret      PRINCES HILL       NaN
# 14                   Pigdon        Street      PRINCES HILL       NaN
# 15              Mc Cutcheon           Way       COLLINGWOOD       NaN
# 16                      NaN           NaN               NaN       NaN
# 17                      NaN           Hwy    CHIRNSIDE PARK       NaN
# 18                      NaN          Road             CORIO       NaN
# 19                      NaN         Close       OCEAN GROVE       NaN
# 20                 Melaluka          Road           LEOPOLD       NaN
# 21                      NaN        Street        HERNE HILL       NaN
# 22                      NaN          Road           LEOPOLD       NaN
# 23                      NaN        Street     PORTARLINGTON       NaN
# 24                      NaN          Road       OCEAN GROVE       NaN
# 25                      NaN          Road           BELMONT       NaN
# 26                      NaN         Drive           NEWTOWN       NaN
# 27                      NaN          Road           BELMONT       NaN
# 28                      NaN         Close       OCEAN GROVE       NaN
# 29                      NaN        Street        HERNE HILL       NaN
# ..                      ...           ...               ...       ...
# 409              Smithfield          Road        FLEMINGTON       NaN
# 410                  Buncle        Street   NORTH MELBOURNE       NaN
# 411                   Royal        Parade         PARKVILLE       NaN
# 412               Macarthur          Road         PARKVILLE       NaN
# 413                   Brens         Drive         PARKVILLE       NaN
# 414               Rathdowne        Street           CARLTON       NaN
# 415                  Altona        Street        KENSINGTON       NaN
# 416                  Buncle        Street   NORTH MELBOURNE       NaN
# 417                   Arden        Street   NORTH MELBOURNE       NaN
# 418               Nicholson        Street         MELBOURNE       NaN
# 419                  Pasley  Street North       SOUTH YARRA       NaN
# 420                 William        Street         MELBOURNE       NaN
# 421                Speakman        Street        KENSINGTON       NaN
# 422                 Olympic     Boulevard         MELBOURNE       NaN
# 423                   Royal        Parade         PARKVILLE       NaN
# 424                   Royal        Parade         PARKVILLE       NaN
# 425               Macarthur          Road         PARKVILLE       NaN
# 426               Macarthur          Road         PARKVILLE       NaN
# 427                  Pasley  Street North       SOUTH YARRA       NaN
# 428                    Punt          Road          RICHMOND       NaN
# 429              Kensington          Road  SOUTH KENSINGTON       NaN
# 430                   Royal        Parade         PARKVILLE       NaN
# 431               Rathdowne        Street           CARLTON       NaN
# 432                  Altona        Street        KENSINGTON       NaN
# 433                     NaN           NaN               NaN       NaN
# 434                   Emily        Street           SEYMOUR       NaN
# 435   Broadford - Glenaroua          Road        CARLSRUSHE       NaN
# 436      Carlsrushe Central          Road        CARLSRUSHE       NaN
# 437  Broadford - Flowerdale          Road      STRATH CREEK       NaN
# 438                 Trawool           NaN          TALAROOK       NaN
#
#       Latitude   Longitude                     SportsPlayed              LGA
# 0   -37.840037  144.717830                     Rugby League          WYNDHAM
# 1   -37.803256  144.989030                       Basketball            YARRA
# 2   -37.800909  144.979157                       Basketball            YARRA
# 3   -37.829690  145.012699                       Basketball            YARRA
# 4   -37.781818  144.966587                       Basketball            YARRA
# 5   -37.806529  145.010120                          Cycling       BOROONDARA
# 6   -37.793700  145.015130                          Cycling       BOROONDARA
# 7   -37.805467  144.974449     Fitness / Gymnasium Workouts            YARRA
# 8   -37.818380  145.001525     Fitness / Gymnasium Workouts            YARRA
# 9   -37.801956  144.988164     Fitness / Gymnasium Workouts            YARRA
# 10  -37.829690  145.012699                          Netball            YARRA
# 11  -37.799975  145.008575                           Soccer            YARRA
# 12  -37.803256  144.989030  Soccer (Indoor Soccer / Futsal)            YARRA
# 13  -37.781818  144.966587  Soccer (Indoor Soccer / Futsal)            YARRA
# 14  -37.780992  144.962781  Soccer (Indoor Soccer / Futsal)        MELBOURNE
# 15  -37.803256  144.989030                       Volleyball            YARRA
# 16  -37.970049  145.301056                          Cycling            CASEY
# 17  -37.766357  145.305667                   Park / Reserve     YARRA RANGES
# 18  -38.078959  144.353257                   Park / Reserve  GREATER GEELONG
# 19  -38.267278  144.548822                   Park / Reserve  GREATER GEELONG
# 20  -38.202327  144.453856        Australian Rules Football  GREATER GEELONG
# 21  -38.131441  144.327187                   Park / Reserve  GREATER GEELONG
# 22  -38.184416  144.456859                   Park / Reserve  GREATER GEELONG
# 23  -38.113612  144.643431                   Park / Reserve  GREATER GEELONG
# 24  -38.259389  144.537787                   Park / Reserve  GREATER GEELONG
# 25  -38.182921  144.355990                   Park / Reserve  GREATER GEELONG
# 26  -38.152708  144.324953                   Park / Reserve  GREATER GEELONG
# 27  -38.182921  144.355990                   Park / Reserve  GREATER GEELONG
# 28  -38.267278  144.548822                   Park / Reserve  GREATER GEELONG
# 29  -38.131441  144.327187                   Park / Reserve  GREATER GEELONG
# ..         ...         ...                              ...              ...
# 409 -37.788141  144.923465                           Soccer        MELBOURNE
# 410 -37.793231  144.939922                           Soccer        MELBOURNE
# 411 -37.785105  144.960662                           Soccer        MELBOURNE
# 412 -37.783169  144.949402                           Soccer        MELBOURNE
# 413 -37.783169  144.949402                           Soccer        MELBOURNE
# 414 -37.792875  144.969005  Soccer (Indoor Soccer / Futsal)        MELBOURNE
# 415 -37.796187  144.924603  Soccer (Indoor Soccer / Futsal)        MELBOURNE
# 416 -37.793231  144.939922  Soccer (Indoor Soccer / Futsal)        MELBOURNE
# 417 -37.799291  144.941973  Soccer (Indoor Soccer / Futsal)        MELBOURNE
# 418 -37.802325  144.972860                 Tennis (Outdoor)        MELBOURNE
# 419 -37.840400  144.981583                 Tennis (Outdoor)        MELBOURNE
# 420 -37.809912  144.954430                 Tennis (Outdoor)        MELBOURNE
# 421 -37.794534  144.915836                 Tennis (Outdoor)        MELBOURNE
# 422 -37.821437  144.979104                 Tennis (Outdoor)        MELBOURNE
# 423 -37.785105  144.960662                 Tennis (Outdoor)        MELBOURNE
# 424 -37.785105  144.960662                 Tennis (Outdoor)        MELBOURNE
# 425 -37.783169  144.949402                 Tennis (Outdoor)        MELBOURNE
# 426 -37.783169  144.949402                 Tennis (Outdoor)        MELBOURNE
# 427 -37.840400  144.981583                   Touch Football        MELBOURNE
# 428 -37.825859  144.986675                   Touch Football        MELBOURNE
# 429 -37.797812  144.924151                   Touch Football        MELBOURNE
# 430 -37.785105  144.960662                   Touch Football        MELBOURNE
# 431 -37.792875  144.969005                       Volleyball        MELBOURNE
# 432 -37.796187  144.924603                       Volleyball        MELBOURNE
# 433 -34.210357  142.024467                     Rugby League          MILDURA
# 434 -37.017126  145.133140                          Cycling         MITCHELL
# 435 -37.311472  144.518540                          Cycling   MACEDON RANGES
# 436 -37.311472  144.518540                          Cycling   MACEDON RANGES
# 437 -37.236452  145.220540                          Cycling      MURRINDINDI
# 438 -37.094302  145.100900                          Cycling         MITCHELL
#
# [439 rows x 11 columns]

# %%
# reverse geocoding 

examp = 'https://maps.googleapis.com/maps/api/geocode/json?latlng={},{}&key={}'

for i in range(df2.shape[0]):
    lng = df2.iloc[i,:].Longitude
    lat = df2.iloc[i,:].Latitude
    

    q = examp.format(lat, lng, api_key)
    #print(q)
    res = requests.get(q).json()
    result = res.get('results')
    
    # only for valid results
    if len(result) != 0:
        pp = [p.get('short_name') for p in result[0].get('address_components') if p.get('types') == ['postal_code']]
        ss = [p.get('short_name') for p in result[0].get('address_components') if 'locality' in p.get('types')]
        postcode = pp[0] if len(pp) > 0 else None
        sub = ss[0] if len(ss) > 0 else None
        print(postcode,sub)
        
        df2.loc[i,'Postcode'] = postcode  
        df2.loc[i,'SuburbTown'] = sub
        
        #print(postcode, sub)
        #if df2.iloc[i,:].SuburbTown == np.nan:
            #print('yes')
            #df2.iloc[i,:].SuburbTown = [p.get('short_name') for p in result[0].get('address_components') if 'locality' in p.get('types')][0]

        
    # uncomment for tesing
    #if i == 8:
        #break
print('done')
# Out:
# 3029 Truganina
# C:\Users\jenny_lai\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# 3066 Collingwood
# 3065 Fitzroy
# 3121 Burnley
# 3054 Princes Hill
# 3101 Kew
# 3101 Kew
# 3065 Fitzroy
# 3121 Richmond
# 3066 Collingwood
# 3121 Burnley
# 3078 Fairfield
# 3066 Collingwood
# 3054 Princes Hill
# 3054 Princes Hill
# 3066 Collingwood
# 3804 Narre Warren North
# 3116 Chirnside Park
# 3214 Corio
# 3226 Ocean Grove
# 3224 Leopold
# 3218 Herne Hill
# 3224 Leopold
# 3223 Portarlington
# 3226 Ocean Grove
# 3216 Belmont
# 3220 Newtown
# 3216 Belmont
# 3226 Ocean Grove
# 3218 Herne Hill
# 3218 Herne Hill
# 3224 Leopold
# 3224 Leopold
# 3223 Portarlington
# 3226 Ocean Grove
# 3216 Belmont
# 3216 Belmont
# 3216 Belmont
# 3216 Wandana Heights
# 3220 Newtown
# 3216 Belmont
# 3219 East Geelong
# 3211 Little River
# 3211 Little River
# 3211 Little River
# 3226 Ocean Grove
# 3226 Ocean Grove
# 3240 Paraparap
# 3331 Sutherlands Creek
# 3211 Little River
# 3222 Drysdale
# 3218 Herne Hill
# 3224 Leopold
# 3223 Portarlington
# 3224 Leopold
# 3226 Ocean Grove
# 3218 Geelong West
# 3224 Leopold
# 3224 Leopold
# 3224 Leopold
# 3216 Grovedale
# 3223 Portarlington
# 3223 Portarlington
# 3226 Ocean Grove
# 3216 Wandana Heights
# 3216 Wandana Heights
# 3162 Caulfield South
# 3351 Cape Clear
# 3345 Gordon
# 3333 Meredith
# 3330 Rokewood
# 3331 Maude
# 3351 Snake Valley
# 3364 Kingston
# 3018 Altona
# 3691 Dederang
# 3691 Dederang
# 3737 Gapsted
# 3741 Harrietville
# 3699 Mount Beauty
# 3691 Dederang
# 3691 Dederang
# 3691 Gundowring
# 3377 Ararat
# 3377 Ararat
# 3377 Armstrong
# 3377 Ararat
# 3377 Ararat
# 3350 Black Hill
# 3352 Burrumbeet
# 3352 Burrumbeet
# 3352 Learmonth
# 3352 Miners Rest
# 3350 Newington
# 3350 Newington
# 3984 Coronet Bay
# 3984 Coronet Bay
# 3995 Wonthaggi
# 3996 Inverloch
# 3990 Glen Forbes
# 3820 Warragul
# 3823 Yarragon
# 3822 Darnum
# 3825 Erica
# 3833 Baw Baw Village
# 3821 Shady Creek
# 3822 Darnum
# 3823 Yarragon
# 3820 Warragul
# 3833 Noojee
# 3820 Warragul
# 3188 Hampton
# 3186 Brighton
# 3188 Hampton
# 3187 Brighton East
# 3187 Brighton East
# 3190 Highett
# 3191 Sandringham
# 3186 Brighton
# 3186 Brighton
# 3188 Hampton
# 3188 Hampton
# 3188 Hampton
# 3018 Altona
# 3401 Dooen
# 3757 Humevale
# 3688 Barnawartha
# 3683 Chiltern
# 3687 Wahgunyah
# 3688 Barnawartha
# 3683 Chiltern
# 3691 Kiewa
# 3685 Rutherglen
# 3747 Stanley
# 3749 Yackandandah
# 3688 Barnawartha
# 3747 Beechworth
# 3683 Chiltern
# 3685 Rutherglen
# 3683 Chiltern
# 3687 Wahgunyah
# 3683 Chiltern
# 3687 Wahgunyah
# 3747 Beechworth
# 3683 Chiltern
# 3685 Rutherglen
# 3747 Beechworth
# 3683 Chiltern
# 3691 Kiewa
# 3687 Wahgunyah
# 3749 Yackandandah
# 3195 Braeside
# 3156 Ferntree Gully
# 3156 Ferntree Gully
# 3156 Ferntree Gully
# 3870 Boolarra
# 3825 Willow Grove
# 3844 Flynn
# 3228 Torquay
# 3594 Nyah
# 3589 Woorinen
# 3594 Nyah
# 3589 Woorinen
# 3549 Robinvale
# 3586 Murraydale
# 3700 Tallangatta
# 3691 Bethanga
# 3701 Eskdale
# 3700 Tallangatta
# 3691 Bethanga
# 3700 Tallangatta
# 3691 Bethanga
# 3691 Bethanga
# 3700 Tallangatta
# 3678 Wangaratta South
# 3678 Killawarra
# None None
# 3673 Winton
# 3732 Moyhu
# 3678 Wangaratta South
# 3675 Greta South
# 3280 Warrnambool
# 3280 Warrnambool
# 3966 Binginwarri
# 3971 Tarraville
# 3874 Woodside
# 3859 Tinamba
# 3874 Woodside
# 3966 Binginwarri
# 3874 Woodside
# 3128 Box Hill
# 3133 Vermont South
# 3995 St Clair
# 3128 Box Hill
# 3128 Box Hill
# 3076 Epping
# 3752 South Morang
# 3075 Lalor
# 3754 Doreen
# 3076 Epping
# 3076 Epping
# 3076 Epping
# 3076 Epping
# 3075 Lalor
# 3754 Doreen
# 3691 Bellbridge
# 3690 West Wodonga
# 3690 West Wodonga
# 3690 West Wodonga
# 3551 Strathfieldsaye
# 3550 Spring Gully
# 3550 East Bendigo
# 3550 Ironbark
# 3555 Kangaroo Flat
# 3550 Ironbark
# 3550 Ironbark
# 3555 Kangaroo Flat
# 3516 Leichardt
# 3551 Lockwood
# 3551 Lockwood South
# 3515 Marong
# 3550 Quarry Hill
# 3225 Point Lonsdale
# 3622 Koyuga
# 3563 Lockington
# 3561 Fairy Dell
# 3564 Echuca
# 3815 Bunyip
# 3814 Cora Lynn
# 3814 Cora Lynn
# 3808 Beaconsfield Upper
# 3984 Lang Lang
# 3816 Modella
# 3809 Officer
# 3783 Gembrook
# 3805 Narre Warren South
# 3977 Devon Meadows
# 3977 Devon Meadows
# 3977 Devon Meadows
# 3639 Picola
# 3039 Moonee Ponds
# 3039 Moonee Ponds
# 3340 Balliang
# 3340 Balliang
# 3352 Dunnstown
# 3340 Balliang
# 3352 Wallace
# 3918 Bittern
# 3927 Somers
# 3463 Maldon
# 3284 Port Fairy
# 3284 Port Fairy
# 3757 Kinglake Central
# 3711 Buxton
# 3779 Marysville
# 3658 Strath Creek
# None None
# 3725 Major Plains
# 3646 Mount Major
# 3956 Meeniyan
# 3956 Meeniyan
# 3954 Koonwarra
# 3956 Meeniyan
# 3953 Nerrena
# 3953 Leongatha
# 3953 Koorooman
# 3953 Leongatha South
# None None
# 3956 Meeniyan
# 3956 Meeniyan
# 3956 Dumbalk North
# 3954 Koonwarra
# 3956 Meeniyan
# 3241 Winchelsea
# 3977 Devon Meadows
# 3977 Devon Meadows
# 3977 Devon Meadows
# 3806 Harkaway
# 3806 Harkaway
# 3977 Devon Meadows
# 3977 Devon Meadows
# 3977 Devon Meadows
# 3450 Castlemaine
# 3251 Beeac
# 3250 Colac East
# 3236 Forrest
# 3267 Scotts Creek
# 3260 Camperdown
# 3260 Camperdown
# 3264 Terang
# 3267 Scotts Creek
# 3267 Scotts Creek
# 3885 Bruthen
# 3885 Buchan
# 3895 Ensay
# 3895 Ensay
# 3865 Lindenow
# 3896 Swifts Creek
# 3885 Bruthen
# 3885 Buchan
# 3890 Cann River
# 3865 Lindenow
# 3860 Briagolong
# 3909 Kalimna West
# 3858 Heyfield
# 3860 Maffra
# 3862 Munro
# 3862 Stratford
# 3859 Newry
# 3862 Stratford
# 3859 Newry
# 3859 Tinamba
# 3885 Buchan
# 3895 Ensay
# 3895 Ensay
# 3885 Bruthen
# 3885 Buchan
# 3895 Ensay
# 3895 Ensay
# 3865 Lindenow
# 3896 Swifts Creek
# 3885 Bruthen
# 3885 Buchan
# 3890 Cann River
# 3895 Ensay
# 3895 Ensay
# 3864 Glenaladale
# 3865 Lindenow
# 3875 Sarsfield
# 3896 Swifts Creek
# 3198 Seaford
# 3444 Kyneton
# 3723 Boorolite
# 3442 Newham
# 3429 Sunbury
# 3429 Sunbury
# 3437 Bullengarook
# 3722 Mansfield
# 3722 Mansfield
# 3722 Mansfield
# 3722 Mansfield
# 3722 Mansfield
# 3723 Boorolite
# 3722 Mansfield
# 3722 Mansfield
# 3723 Mount Buller
# 3723 Tolmie
# 3722 Mansfield
# 3722 Mansfield
# 3723 Tolmie
# 3030 Werribee
# 3008 Docklands
# 3141 South Yarra
# 3121 Cremorne
# 3031 Kensington
# 3031 Kensington
# 3002 East Melbourne
# 3051 North Melbourne
# 3054 Carlton North
# 3004 Melbourne
# 3052 Parkville
# 3054 Carlton North
# 3053 Carlton
# 3052 Parkville
# 3053 Carlton
# 3031 Kensington
# 3051 North Melbourne
# 3051 North Melbourne
# 3052 Parkville
# 3004 Melbourne
# None None
# 3000 Melbourne
# 3053 Carlton
# 3051 North Melbourne
# 3004 Melbourne
# 3000 Melbourne
# 3000 Melbourne
# 3000 Melbourne
# 3000 Melbourne
# 3000 Melbourne
# 3003 West Melbourne
# 3051 North Melbourne
# 3051 North Melbourne
# 3000 Carlton
# 3205 South Melbourne
# 3003 West Melbourne
# 3004 Melbourne
# 3006 Southbank
# 3053 Carlton
# 3000 Melbourne
# 3003 West Melbourne
# 3052 Parkville
# 3053 Carlton
# 3031 Kensington
# 3051 North Melbourne
# 3052 Parkville
# 3004 Melbourne
# 3008 Docklands
# 3121 Cremorne
# 3004 Melbourne
# 3008 Docklands
# 3141 South Yarra
# 3121 Cremorne
# 3052 Parkville
# 3004 Melbourne
# 3141 South Yarra
# 3121 Cremorne
# 3031 Kensington
# 3004 Melbourne
# 3031 Kensington
# 3051 North Melbourne
# 3054 Carlton North
# 3052 Parkville
# 3052 Parkville
# 3053 Carlton
# 3031 Kensington
# 3051 North Melbourne
# 3051 North Melbourne
# 3053 Carlton
# 3141 South Yarra
# 3003 West Melbourne
# 3031 Kensington
# 3004 Melbourne
# 3054 Carlton North
# 3054 Carlton North
# 3052 Parkville
# 3052 Parkville
# 3141 South Yarra
# 3121 Cremorne
# 3031 Kensington
# 3054 Carlton North
# 3053 Carlton
# 3031 Kensington
# 3505 Merbein South
# 3660 Seymour
# 3442 Woodend North
# 3442 Woodend North
# 3658 Strath Creek
# 3659 Tallarook
# done

# %%
df2.head(10)
# Out:
#    Facility_ID                                   FacilityName StreetNo  \
# 0   WYNDHA5496                        Clearwood Drive Reserve      NaN
# 1  YARRAC11029                  Collingwood Secondary College      NaN
# 2  YARRAC11032                      Fitzroy Secondary  School      NaN
# 3  YARRAC11028                        Melbourne Girls College      NaN
# 4  YARRAC11030                  Princes Hill Seconary College      NaN
# 5   YARRAC5306                                  Kew Boulevard      NaN
# 6   YARRAC5282                           Yarra Boulevard Loop      NaN
# 7  YARRAC11024  Melbourne Aboriginal Sport and Recreation Gym      NaN
# 8  YARRAC11023                           Richmond Boxing Club      NaN
# 9  YARRAC11022                            Stanton Street Hall      NaN
#
#     StreetName StreetType    SuburbTown Postcode   Latitude   Longitude  \
# 0    Clearwood      Drive     Truganina     3029 -37.840037  144.717830
# 1  Mc Cutcheon        Way   Collingwood     3066 -37.803256  144.989030
# 2     Falconer     Street       Fitzroy     3065 -37.800909  144.979157
# 3        Yarra  Boulevard       Burnley     3121 -37.829690  145.012699
# 4       Arnold     Strret  Princes Hill     3054 -37.781818  144.966587
# 5          Kew  Boulevard           Kew     3101 -37.806529  145.010120
# 6        Yarra  Boulevard           Kew     3101 -37.793700  145.015130
# 7     Gertrude     Street       Fitzroy     3065 -37.805467  144.974449
# 8     Gleadell     Street      Richmond     3121 -37.818380  145.001525
# 9      Stanton     Street   COLLINGWOOD      NaN -37.801956  144.988164
#
#                    SportsPlayed         LGA
# 0                  Rugby League     WYNDHAM
# 1                    Basketball       YARRA
# 2                    Basketball       YARRA
# 3                    Basketball       YARRA
# 4                    Basketball       YARRA
# 5                       Cycling  BOROONDARA
# 6                       Cycling  BOROONDARA
# 7  Fitness / Gymnasium Workouts       YARRA
# 8  Fitness / Gymnasium Workouts       YARRA
# 9  Fitness / Gymnasium Workouts       YARRA

# %%
df3 = df2.copy()
df3.head()
# Out:
#    Facility_ID                   FacilityName StreetNo   StreetName  \
# 0   WYNDHA5496        Clearwood Drive Reserve      NaN    Clearwood
# 1  YARRAC11029  Collingwood Secondary College      NaN  Mc Cutcheon
# 2  YARRAC11032      Fitzroy Secondary  School      NaN     Falconer
# 3  YARRAC11028        Melbourne Girls College      NaN        Yarra
# 4  YARRAC11030  Princes Hill Seconary College      NaN       Arnold
#
#   StreetType    SuburbTown Postcode   Latitude   Longitude  SportsPlayed  \
# 0      Drive     Truganina     3029 -37.840037  144.717830  Rugby League
# 1        Way   Collingwood     3066 -37.803256  144.989030    Basketball
# 2     Street       Fitzroy     3065 -37.800909  144.979157    Basketball
# 3  Boulevard       Burnley     3121 -37.829690  145.012699    Basketball
# 4     Strret  Princes Hill     3054 -37.781818  144.966587    Basketball
#
#        LGA
# 0  WYNDHAM
# 1    YARRA
# 2    YARRA
# 3    YARRA
# 4    YARRA

# %%
df3 = df3[~df3.Postcode.isnull()]

# %%
df2.shape
df3.shape
# Out:
# (435, 11)

# %%
df_new = df[~(df.Postcode.isnull())]

# %%
df_new.reset_index(inplace=True,drop=True)
df_new.head()
# Out:
#    Facility_ID                      FacilityName StreetNo StreetName  \
# 0   WYNDHA8530  Werribee Sports & Fitness Centre      NaN     Ballan
# 1  WYNDHA11288             Hoppers Indoor Sportz      NaN     Graham
# 2   WYNDHA8521           Riverside Indoor Sports       13  Riverside
# 3  WYNDHA11000              Haines Drive Reserve      NaN     Haines
# 4  WYNDHA11000              Haines Drive Reserve      NaN     Haines
#
#   StreetType        SuburbTown  Postcode   Latitude   Longitude  \
# 0       Road          WERRIBEE    3030.0 -37.898601  144.640316
# 1      Court  HOPPERS CROSSING    3029.0 -37.872000  144.727500
# 2     Avenue          WERRIBEE    3030.0 -37.913492  144.659074
# 3       Road      WYNDHAM VALE    3024.0 -37.897069  144.609389
# 4       Road      WYNDHAM VALE    3024.0 -37.897069  144.609389
#
#        SportsPlayed      LGA
# 0           Netball  WYNDHAM
# 1  Netball (Indoor)  WYNDHAM
# 2  Netball (Indoor)  WYNDHAM
# 3      Rugby League  WYNDHAM
# 4       Rugby Union  WYNDHAM

# %%
df_post = pd.concat([df_new, df3])
df_post.head()
# Out:
#    Facility_ID                      FacilityName StreetNo StreetName  \
# 0   WYNDHA8530  Werribee Sports & Fitness Centre      NaN     Ballan
# 1  WYNDHA11288             Hoppers Indoor Sportz      NaN     Graham
# 2   WYNDHA8521           Riverside Indoor Sports       13  Riverside
# 3  WYNDHA11000              Haines Drive Reserve      NaN     Haines
# 4  WYNDHA11000              Haines Drive Reserve      NaN     Haines
#
#   StreetType        SuburbTown Postcode   Latitude   Longitude  \
# 0       Road          WERRIBEE     3030 -37.898601  144.640316
# 1      Court  HOPPERS CROSSING     3029 -37.872000  144.727500
# 2     Avenue          WERRIBEE     3030 -37.913492  144.659074
# 3       Road      WYNDHAM VALE     3024 -37.897069  144.609389
# 4       Road      WYNDHAM VALE     3024 -37.897069  144.609389
#
#        SportsPlayed      LGA
# 0           Netball  WYNDHAM
# 1  Netball (Indoor)  WYNDHAM
# 2  Netball (Indoor)  WYNDHAM
# 3      Rugby League  WYNDHAM
# 4       Rugby Union  WYNDHAM

# %%
df_post.shape
# Out:
# (5536, 11)

# %%
# drop sports types
df5 = df_post.drop(columns=['SportsPlayed'])
df5.head()
# Out:
#    Facility_ID                      FacilityName StreetNo StreetName  \
# 0   WYNDHA8530  Werribee Sports & Fitness Centre      NaN     Ballan
# 1  WYNDHA11288             Hoppers Indoor Sportz      NaN     Graham
# 2   WYNDHA8521           Riverside Indoor Sports       13  Riverside
# 3  WYNDHA11000              Haines Drive Reserve      NaN     Haines
# 4  WYNDHA11000              Haines Drive Reserve      NaN     Haines
#
#   StreetType        SuburbTown Postcode   Latitude   Longitude      LGA
# 0       Road          WERRIBEE     3030 -37.898601  144.640316  WYNDHAM
# 1      Court  HOPPERS CROSSING     3029 -37.872000  144.727500  WYNDHAM
# 2     Avenue          WERRIBEE     3030 -37.913492  144.659074  WYNDHAM
# 3       Road      WYNDHAM VALE     3024 -37.897069  144.609389  WYNDHAM
# 4       Road      WYNDHAM VALE     3024 -37.897069  144.609389  WYNDHAM

# %%
len(df5.Facility_ID.unique().tolist())
# Out:
# 3197

# %%
df5.drop_duplicates(subset='Facility_ID', inplace=True)

# %%
df5.SuburbTown = df5.SuburbTown.str.capitalize()

# %%
df5.shape
# Out:
# (3197, 10)

# %%
df5.head(50)
# Out:
#     Facility_ID                                       FacilityName StreetNo  \
# 0    WYNDHA8530                   Werribee Sports & Fitness Centre      NaN
# 1   WYNDHA11288                              Hoppers Indoor Sportz      NaN
# 2    WYNDHA8521                            Riverside Indoor Sports       13
# 3   WYNDHA11000                               Haines Drive Reserve      NaN
# 5    WYNDHA8514                                   Mossfiel Reserve      NaN
# 6   WYNDHA10998                               Forsyth Road Reserve      NaN
# 8    WYNDHA8502                                        Galvin Park      NaN
# 9    WYNDHA8505                      Grange Reserve Soccer Complex      NaN
# 11  WYNDHA11003                                  Saltwater Reserve      NaN
# 12  WYNDHA11004                         Tom Roberts Parade Reserve      NaN
# 13   WYNDHA8526                        VU Wyndham Sporting Complex      NaN
# 16   WYNDHA8494                                  Cambridge Reserve      NaN
# 17   WYNDHA8495                                     Chirnside Park      NaN
# 20   WYNDHA8508                              Hoppers Crossing Club      NaN
# 21   WYNDHA8510              Jamieson Way Tennis & Netball Complex      NaN
# 22   WYNDHA8512                               Little River Reserve      NaN
# 24   WYNDHA8519                                      Price Reserse      NaN
# 26   WYNDHA8522                          Sanctuary Lakes Golf Club      NaN
# 28   WYNDHA8531                    Willow Green Park Tennis Courts      NaN
# 29  WYNDHA11006                               Wootten Road Reserve      NaN
# 30   WYNDHA8532                        Wyndham Green Tennis Courts      NaN
# 31   WYNDHA8535                                     Wyndham Waters      NaN
# 33  YARRAC11007         Citizen’s Park Oval and Jack Dyer Pavilion      NaN
# 34  YARRAC10978  George Knott Athletics Track and Ray Coverdale...      NaN
# 35  YARRAC10993                  Alfred Crescent Oval and Pavilion      NaN
# 36  YARRAC10967                  Alphington Park Oval and Pavilion      NaN
# 38  YARRAC10972                  Loughan Oval and Johnson Pavilion      NaN
# 39  YARRAC10985                   Ramsden Street Oval and Pavilion      NaN
# 40  YARRAC10962                                      Victoria Park      NaN
# 41  YARRAC10995  W T Peterson Oval & Edinburgh Gardens Change R...      NaN
# 42  YARRAC11054                       All Seasons Personal Fitness       41
# 43  YARRAC11055                 Andrew Baxter Body Concepts Studio       30
# 44  YARRAC11034                         Anytime Fitness Alphington      738
# 45  YARRAC11056                           Anytime Fitness Richmond     8/53
# 46  YARRAC11019                    Australian Institute of Fitness      405
# 47  YARRAC11057                   Balance & Control Pilates Studio      474
# 48  YARRAC10981               Collingwood Housing Estate Gymnasium      NaN
# 49  YARRAC10979                         Collingwood Leisure Centre      NaN
# 50  YARRAC11015                                  CrossFit Richmond      116
# 51  YARRAC11003                                  CrossFit Victoria       62
# 52  YARRAC11037                                  CrossFit Victoria     2/62
# 53  YARRAC11050                               Curves North Fitzroy      278
# 54  YARRAC11035                                 Fernwood - Carlton  193-197
# 55  YARRAC10975                                   Fernwood Carlton      197
# 56  YARRAC11046                                   Fitness 24 Hours      133
# 57  YARRAC11016                                      Fitness First      560
# 58  YARRAC11059                                       Fitness Live        4
# 59  YARRAC11066                                Fitness Ring Studio      488
# 60  YARRAC11051                                   fitness Xplosion      NaN
# 61  YARRAC10992                                    Fitnessland Gym      212
#
#      StreetName StreetType        SuburbTown Postcode   Latitude   Longitude  \
# 0        Ballan       Road          Werribee     3030 -37.898601  144.640316
# 1        Graham      Court  Hoppers crossing     3029 -37.872000  144.727500
# 2     Riverside     Avenue          Werribee     3030 -37.913492  144.659074
# 3        Haines       Road      Wyndham vale     3024 -37.897069  144.609389
# 5        Heaths       Road  Hoppers crossing     3029 -37.877437  144.692478
# 6       Forsyth       Road         Truganina     3029 -37.860804  144.729419
# 8         Shaws       Road          Werribee     3030 -37.887060  144.650409
# 9        Hogans       Road  Hoppers crossing     3029 -37.860885  144.676572
# 11   Point Cook       Road        Point cook     3030 -37.909351  144.752502
# 12   Tom Robert     Parade        Point cook     3030 -37.894010  144.727529
# 13      Hoppers       Lane          Werribee     3030 -37.892629  144.702157
# 16       Barber      Drive  Hoppers crossing     3029 -37.871069  144.675717
# 17       Watton     Street          Werribee     3030 -37.904815  144.652061
# 20       Pannam      Drive  Hoppers crossing     3029 -37.869490  144.692773
# 21     Jamieson        Way        Point cook     3030 -37.896312  144.748532
# 22    You Yangs       Road      Little river     3211 -37.961417  144.497406
# 24        Beach       Road          Werribee     3030 -37.973368  144.691765
# 26  Greg Norman      Drive        Point cook     3030 -37.896097  144.762714
# 28    Spindrift        Way        Point cook     3030 -37.885605  144.751023
# 29      Wootten       Road           Tarneit     3029 -37.856500  144.660000
# 30        Amber      Place      Wyndham vale     3024 -37.887244  144.619546
# 31       Sayers       Road         Truganina     3029 -37.851221  144.726537
# 33     Gleadell     Street          Richmond     3121 -37.817218  145.000351
# 34   Heidelberg       Road      Clifton hill     3068 -37.784205  145.002319
# 35    Brunswick     Street           Fitzroy     3065 -37.787530  144.982377
# 36     Parkview       Road        Alphington     3067 -37.783779  145.029131
# 38         Swan     Street           Burnley     3121 -37.828576  145.020462
# 39      Ramsden     Street         Fairfield     3078 -37.789873  145.003111
# 40       Turner     Street        Abbotsford     3067 -37.798580  144.996607
# 41    Brunswick     Street           Fitzroy     3065 -37.787530  144.982377
# 42       Bridge       Road          Richmond     3121 -37.817479  144.991239
# 43     Cremorne     Street          Richmond     3121 -37.826115  144.990736
# 44   Heidelberg       Road        Alphington     3067 -37.780993  145.031394
# 45       Coppin     Street          Richmond     3121 -37.820398  145.003818
# 46       Church     Street          Richmond     3121 -37.824922  144.998156
# 47     Victoria     Street          Richmond     3121 -37.811511  145.007549
# 48       Hoddle     Street       Collingwood     3066 -37.802870  144.992863
# 49     Turnbull     Street      Clifton hill     3068 -37.787996  144.994351
# 50       Murphy     Street          Richmond     3121 -37.818162  145.009580
# 51         Rose     Street           Fitzroy     3065 -37.795940  144.977530
# 52         Rose     Street           Fitzroy     3065 -37.795964  144.977608
# 53  St. Georges       Road     Fitzroy north     3068 -37.782090  144.985022
# 54    Nicholson     Street           Carlton     3053 -37.795584  144.974952
# 55    Nicholson     Street           Carlton     3053 -37.795621  144.975108
# 56     Johnston     Street           Fitzroy     3065 -37.798090  144.979215
# 57       Church     Street          Richmond     3121 -37.829370  144.996400
# 58   Stephenson     Street          Richmond     3121 -37.820335  145.002458
# 59     Victoria     Street          Richmond     3121 -37.809937  144.994548
# 60  St. Georges       Road     Fitzroy north     3068 -37.791351  144.976277
# 61       Grange       Road         Fairfield     3078 -37.779009  145.025109
#
#           LGA
# 0     WYNDHAM
# 1     WYNDHAM
# 2     WYNDHAM
# 3     WYNDHAM
# 5     WYNDHAM
# 6     WYNDHAM
# 8     WYNDHAM
# 9     WYNDHAM
# 11    WYNDHAM
# 12    WYNDHAM
# 13    WYNDHAM
# 16    WYNDHAM
# 17    WYNDHAM
# 20    WYNDHAM
# 21    WYNDHAM
# 22    WYNDHAM
# 24    WYNDHAM
# 26    WYNDHAM
# 28    WYNDHAM
# 29    WYNDHAM
# 30    WYNDHAM
# 31    WYNDHAM
# 33      YARRA
# 34      YARRA
# 35      YARRA
# 36      YARRA
# 38      YARRA
# 39      YARRA
# 40      YARRA
# 41      YARRA
# 42      YARRA
# 43      YARRA
# 44      YARRA
# 45      YARRA
# 46      YARRA
# 47      YARRA
# 48      YARRA
# 49      YARRA
# 50      YARRA
# 51      YARRA
# 52      YARRA
# 53      YARRA
# 54  MELBOURNE
# 55  MELBOURNE
# 56      YARRA
# 57      YARRA
# 58      YARRA
# 59      YARRA
# 60      YARRA
# 61    DAREBIN

# %%
# separate place and business types
df_type = pd.concat([df_post.Facility_ID, df_post.SportsPlayed], axis=1)
df_type.shape
# Out:
# (5536, 2)

# %%
df_type.head()
# Out:
#    Facility_ID      SportsPlayed
# 0   WYNDHA8530           Netball
# 1  WYNDHA11288  Netball (Indoor)
# 2   WYNDHA8521  Netball (Indoor)
# 3  WYNDHA11000      Rugby League
# 4  WYNDHA11000       Rugby Union

# %%
df_post.head(40)
# Out:
#     Facility_ID                                       FacilityName StreetNo  \
# 0    WYNDHA8530                   Werribee Sports & Fitness Centre      NaN
# 1   WYNDHA11288                              Hoppers Indoor Sportz      NaN
# 2    WYNDHA8521                            Riverside Indoor Sports       13
# 3   WYNDHA11000                               Haines Drive Reserve      NaN
# 4   WYNDHA11000                               Haines Drive Reserve      NaN
# 5    WYNDHA8514                                   Mossfiel Reserve      NaN
# 6   WYNDHA10998                               Forsyth Road Reserve      NaN
# 7   WYNDHA10998                               Forsyth Road Reserve      NaN
# 8    WYNDHA8502                                        Galvin Park      NaN
# 9    WYNDHA8505                      Grange Reserve Soccer Complex      NaN
# 10   WYNDHA8505                      Grange Reserve Soccer Complex      NaN
# 11  WYNDHA11003                                  Saltwater Reserve      NaN
# 12  WYNDHA11004                         Tom Roberts Parade Reserve      NaN
# 13   WYNDHA8526                        VU Wyndham Sporting Complex      NaN
# 14   WYNDHA8521                            Riverside Indoor Sports       13
# 15   WYNDHA8530                   Werribee Sports & Fitness Centre      NaN
# 16   WYNDHA8494                                  Cambridge Reserve      NaN
# 17   WYNDHA8495                                     Chirnside Park      NaN
# 18   WYNDHA8495                                     Chirnside Park      NaN
# 19   WYNDHA8502                                        Galvin Park      NaN
# 20   WYNDHA8508                              Hoppers Crossing Club      NaN
# 21   WYNDHA8510              Jamieson Way Tennis & Netball Complex      NaN
# 22   WYNDHA8512                               Little River Reserve      NaN
# 23   WYNDHA8514                                   Mossfiel Reserve      NaN
# 24   WYNDHA8519                                      Price Reserse      NaN
# 25  WYNDHA11003                                  Saltwater Reserve      NaN
# 26   WYNDHA8522                          Sanctuary Lakes Golf Club      NaN
# 27   WYNDHA8530                   Werribee Sports & Fitness Centre      NaN
# 28   WYNDHA8531                    Willow Green Park Tennis Courts      NaN
# 29  WYNDHA11006                               Wootten Road Reserve      NaN
# 30   WYNDHA8532                        Wyndham Green Tennis Courts      NaN
# 31   WYNDHA8535                                     Wyndham Waters      NaN
# 32   WYNDHA8530                   Werribee Sports & Fitness Centre      NaN
# 33  YARRAC11007         Citizen’s Park Oval and Jack Dyer Pavilion      NaN
# 34  YARRAC10978  George Knott Athletics Track and Ray Coverdale...      NaN
# 35  YARRAC10993                  Alfred Crescent Oval and Pavilion      NaN
# 36  YARRAC10967                  Alphington Park Oval and Pavilion      NaN
# 37  YARRAC11007         Citizen’s Park Oval and Jack Dyer Pavilion      NaN
# 38  YARRAC10972                  Loughan Oval and Johnson Pavilion      NaN
# 39  YARRAC10985                   Ramsden Street Oval and Pavilion      NaN
#
#      StreetName StreetType        SuburbTown Postcode   Latitude   Longitude  \
# 0        Ballan       Road          WERRIBEE     3030 -37.898601  144.640316
# 1        Graham      Court  HOPPERS CROSSING     3029 -37.872000  144.727500
# 2     Riverside     Avenue          WERRIBEE     3030 -37.913492  144.659074
# 3        Haines       Road      WYNDHAM VALE     3024 -37.897069  144.609389
# 4        Haines       Road      WYNDHAM VALE     3024 -37.897069  144.609389
# 5        Heaths       Road  HOPPERS CROSSING     3029 -37.877437  144.692478
# 6       Forsyth       Road         TRUGANINA     3029 -37.860804  144.729419
# 7       Forsyth       Road         TRUGANINA     3029 -37.860804  144.729419
# 8         Shaws       Road          WERRIBEE     3030 -37.887060  144.650409
# 9        Hogans       Road  HOPPERS CROSSING     3029 -37.860885  144.676572
# 10       Hogans       Road  HOPPERS CROSSING     3029 -37.860885  144.676572
# 11   Point Cook       Road        POINT COOK     3030 -37.909351  144.752502
# 12   Tom Robert     Parade        POINT COOK     3030 -37.894010  144.727529
# 13      Hoppers       Lane          WERRIBEE     3030 -37.892629  144.702157
# 14    Riverside     Avenue          WERRIBEE     3030 -37.913492  144.659074
# 15       Ballan       Road          WERRIBEE     3030 -37.898601  144.640316
# 16       Barber      Drive  HOPPERS CROSSING     3029 -37.871069  144.675717
# 17       Watton     Street          WERRIBEE     3030 -37.904815  144.652061
# 18       Watton     Street          WERRIBEE     3030 -37.904815  144.652061
# 19        Shaws       Road          WERRIBEE     3030 -37.887060  144.650409
# 20       Pannam      Drive  HOPPERS CROSSING     3029 -37.869490  144.692773
# 21     Jamieson        Way        POINT COOK     3030 -37.896312  144.748532
# 22    You Yangs       Road      LITTLE RIVER     3211 -37.961417  144.497406
# 23       Heaths       Road  HOPPERS CROSSING     3029 -37.877437  144.692478
# 24        Beach       Road          WERRIBEE     3030 -37.973368  144.691765
# 25   Point Cook       Road        POINT COOK     3030 -37.909351  144.752502
# 26  Greg Norman      Drive        POINT COOK     3030 -37.896097  144.762714
# 27       Ballan       Road          WERRIBEE     3030 -37.898601  144.640316
# 28    Spindrift        Way        POINT COOK     3030 -37.885605  144.751023
# 29      Wootten       Road           TARNEIT     3029 -37.856500  144.660000
# 30        Amber      Place      WYNDHAM VALE     3024 -37.887244  144.619546
# 31       Sayers       Road         TRUGANINA     3029 -37.851221  144.726537
# 32       Ballan       Road          WERRIBEE     3030 -37.898601  144.640316
# 33     Gleadell     Street          RICHMOND     3121 -37.817218  145.000351
# 34   Heidelberg       Road      CLIFTON HILL     3068 -37.784205  145.002319
# 35    Brunswick     Street           FITZROY     3065 -37.787530  144.982377
# 36     Parkview       Road        ALPHINGTON     3067 -37.783779  145.029131
# 37     Gleadell     Street          RICHMOND     3121 -37.817218  145.000351
# 38         Swan     Street           BURNLEY     3121 -37.828576  145.020462
# 39      Ramsden     Street         FAIRFIELD     3078 -37.789873  145.003111
#
#                        SportsPlayed      LGA
# 0                           Netball  WYNDHAM
# 1                  Netball (Indoor)  WYNDHAM
# 2                  Netball (Indoor)  WYNDHAM
# 3                      Rugby League  WYNDHAM
# 4                       Rugby Union  WYNDHAM
# 5                       Rugby Union  WYNDHAM
# 6                            Soccer  WYNDHAM
# 7                            Soccer  WYNDHAM
# 8                            Soccer  WYNDHAM
# 9                            Soccer  WYNDHAM
# 10                           Soccer  WYNDHAM
# 11                           Soccer  WYNDHAM
# 12                           Soccer  WYNDHAM
# 13                           Soccer  WYNDHAM
# 14  Soccer (Indoor Soccer / Futsal)  WYNDHAM
# 15                     Table Tennis  WYNDHAM
# 16                 Tennis (Outdoor)  WYNDHAM
# 17                 Tennis (Outdoor)  WYNDHAM
# 18                 Tennis (Outdoor)  WYNDHAM
# 19                 Tennis (Outdoor)  WYNDHAM
# 20                 Tennis (Outdoor)  WYNDHAM
# 21                 Tennis (Outdoor)  WYNDHAM
# 22                 Tennis (Outdoor)  WYNDHAM
# 23                 Tennis (Outdoor)  WYNDHAM
# 24                 Tennis (Outdoor)  WYNDHAM
# 25                 Tennis (Outdoor)  WYNDHAM
# 26                 Tennis (Outdoor)  WYNDHAM
# 27                 Tennis (Outdoor)  WYNDHAM
# 28                 Tennis (Outdoor)  WYNDHAM
# 29                 Tennis (Outdoor)  WYNDHAM
# 30                 Tennis (Outdoor)  WYNDHAM
# 31                 Tennis (Outdoor)  WYNDHAM
# 32                       Volleyball  WYNDHAM
# 33                        Athletics    YARRA
# 34                        Athletics    YARRA
# 35        Australian Rules Football    YARRA
# 36        Australian Rules Football    YARRA
# 37        Australian Rules Football    YARRA
# 38        Australian Rules Football    YARRA
# 39        Australian Rules Football    YARRA

# %%
sportstype = df_type.groupby('Facility_ID')['SportsPlayed'].apply(','.join).reset_index()

# %%
sportstype.shape
# Out:
# (3197, 2)

# %%
sportstype.head()
# Out:
#    Facility_ID                                       SportsPlayed
# 0  ALPINE10918                                             Soccer
# 1  ALPINE10919                                         Basketball
# 2  ALPINE10920                       Fitness / Gymnasium Workouts
# 3  ALPINE10924  Australian Rules Football,Netball,Tennis (Outd...
# 4  ALPINE10925                                     Park / Reserve

# %%
len(sportstype.Facility_ID.unique().tolist())
# Out:
# 3197

# %%
len(df5.Facility_ID.unique().tolist())
# Out:
# 3197

# %%
new = pd.merge(df5,sportstype, on = 'Facility_ID')

# %%
new.shape
# Out:
# (3197, 11)

# %%
new.head(50)
# Out:
#     Facility_ID                                       FacilityName StreetNo  \
# 0    WYNDHA8530                   Werribee Sports & Fitness Centre      NaN
# 1   WYNDHA11288                              Hoppers Indoor Sportz      NaN
# 2    WYNDHA8521                            Riverside Indoor Sports       13
# 3   WYNDHA11000                               Haines Drive Reserve      NaN
# 4    WYNDHA8514                                   Mossfiel Reserve      NaN
# 5   WYNDHA10998                               Forsyth Road Reserve      NaN
# 6    WYNDHA8502                                        Galvin Park      NaN
# 7    WYNDHA8505                      Grange Reserve Soccer Complex      NaN
# 8   WYNDHA11003                                  Saltwater Reserve      NaN
# 9   WYNDHA11004                         Tom Roberts Parade Reserve      NaN
# 10   WYNDHA8526                        VU Wyndham Sporting Complex      NaN
# 11   WYNDHA8494                                  Cambridge Reserve      NaN
# 12   WYNDHA8495                                     Chirnside Park      NaN
# 13   WYNDHA8508                              Hoppers Crossing Club      NaN
# 14   WYNDHA8510              Jamieson Way Tennis & Netball Complex      NaN
# 15   WYNDHA8512                               Little River Reserve      NaN
# 16   WYNDHA8519                                      Price Reserse      NaN
# 17   WYNDHA8522                          Sanctuary Lakes Golf Club      NaN
# 18   WYNDHA8531                    Willow Green Park Tennis Courts      NaN
# 19  WYNDHA11006                               Wootten Road Reserve      NaN
# 20   WYNDHA8532                        Wyndham Green Tennis Courts      NaN
# 21   WYNDHA8535                                     Wyndham Waters      NaN
# 22  YARRAC11007         Citizen’s Park Oval and Jack Dyer Pavilion      NaN
# 23  YARRAC10978  George Knott Athletics Track and Ray Coverdale...      NaN
# 24  YARRAC10993                  Alfred Crescent Oval and Pavilion      NaN
# 25  YARRAC10967                  Alphington Park Oval and Pavilion      NaN
# 26  YARRAC10972                  Loughan Oval and Johnson Pavilion      NaN
# 27  YARRAC10985                   Ramsden Street Oval and Pavilion      NaN
# 28  YARRAC10962                                      Victoria Park      NaN
# 29  YARRAC10995  W T Peterson Oval & Edinburgh Gardens Change R...      NaN
# 30  YARRAC11054                       All Seasons Personal Fitness       41
# 31  YARRAC11055                 Andrew Baxter Body Concepts Studio       30
# 32  YARRAC11034                         Anytime Fitness Alphington      738
# 33  YARRAC11056                           Anytime Fitness Richmond     8/53
# 34  YARRAC11019                    Australian Institute of Fitness      405
# 35  YARRAC11057                   Balance & Control Pilates Studio      474
# 36  YARRAC10981               Collingwood Housing Estate Gymnasium      NaN
# 37  YARRAC10979                         Collingwood Leisure Centre      NaN
# 38  YARRAC11015                                  CrossFit Richmond      116
# 39  YARRAC11003                                  CrossFit Victoria       62
# 40  YARRAC11037                                  CrossFit Victoria     2/62
# 41  YARRAC11050                               Curves North Fitzroy      278
# 42  YARRAC11035                                 Fernwood - Carlton  193-197
# 43  YARRAC10975                                   Fernwood Carlton      197
# 44  YARRAC11046                                   Fitness 24 Hours      133
# 45  YARRAC11016                                      Fitness First      560
# 46  YARRAC11059                                       Fitness Live        4
# 47  YARRAC11066                                Fitness Ring Studio      488
# 48  YARRAC11051                                   fitness Xplosion      NaN
# 49  YARRAC10992                                    Fitnessland Gym      212
#
#      StreetName StreetType        SuburbTown Postcode   Latitude   Longitude  \
# 0        Ballan       Road          Werribee     3030 -37.898601  144.640316
# 1        Graham      Court  Hoppers crossing     3029 -37.872000  144.727500
# 2     Riverside     Avenue          Werribee     3030 -37.913492  144.659074
# 3        Haines       Road      Wyndham vale     3024 -37.897069  144.609389
# 4        Heaths       Road  Hoppers crossing     3029 -37.877437  144.692478
# 5       Forsyth       Road         Truganina     3029 -37.860804  144.729419
# 6         Shaws       Road          Werribee     3030 -37.887060  144.650409
# 7        Hogans       Road  Hoppers crossing     3029 -37.860885  144.676572
# 8    Point Cook       Road        Point cook     3030 -37.909351  144.752502
# 9    Tom Robert     Parade        Point cook     3030 -37.894010  144.727529
# 10      Hoppers       Lane          Werribee     3030 -37.892629  144.702157
# 11       Barber      Drive  Hoppers crossing     3029 -37.871069  144.675717
# 12       Watton     Street          Werribee     3030 -37.904815  144.652061
# 13       Pannam      Drive  Hoppers crossing     3029 -37.869490  144.692773
# 14     Jamieson        Way        Point cook     3030 -37.896312  144.748532
# 15    You Yangs       Road      Little river     3211 -37.961417  144.497406
# 16        Beach       Road          Werribee     3030 -37.973368  144.691765
# 17  Greg Norman      Drive        Point cook     3030 -37.896097  144.762714
# 18    Spindrift        Way        Point cook     3030 -37.885605  144.751023
# 19      Wootten       Road           Tarneit     3029 -37.856500  144.660000
# 20        Amber      Place      Wyndham vale     3024 -37.887244  144.619546
# 21       Sayers       Road         Truganina     3029 -37.851221  144.726537
# 22     Gleadell     Street          Richmond     3121 -37.817218  145.000351
# 23   Heidelberg       Road      Clifton hill     3068 -37.784205  145.002319
# 24    Brunswick     Street           Fitzroy     3065 -37.787530  144.982377
# 25     Parkview       Road        Alphington     3067 -37.783779  145.029131
# 26         Swan     Street           Burnley     3121 -37.828576  145.020462
# 27      Ramsden     Street         Fairfield     3078 -37.789873  145.003111
# 28       Turner     Street        Abbotsford     3067 -37.798580  144.996607
# 29    Brunswick     Street           Fitzroy     3065 -37.787530  144.982377
# 30       Bridge       Road          Richmond     3121 -37.817479  144.991239
# 31     Cremorne     Street          Richmond     3121 -37.826115  144.990736
# 32   Heidelberg       Road        Alphington     3067 -37.780993  145.031394
# 33       Coppin     Street          Richmond     3121 -37.820398  145.003818
# 34       Church     Street          Richmond     3121 -37.824922  144.998156
# 35     Victoria     Street          Richmond     3121 -37.811511  145.007549
# 36       Hoddle     Street       Collingwood     3066 -37.802870  144.992863
# 37     Turnbull     Street      Clifton hill     3068 -37.787996  144.994351
# 38       Murphy     Street          Richmond     3121 -37.818162  145.009580
# 39         Rose     Street           Fitzroy     3065 -37.795940  144.977530
# 40         Rose     Street           Fitzroy     3065 -37.795964  144.977608
# 41  St. Georges       Road     Fitzroy north     3068 -37.782090  144.985022
# 42    Nicholson     Street           Carlton     3053 -37.795584  144.974952
# 43    Nicholson     Street           Carlton     3053 -37.795621  144.975108
# 44     Johnston     Street           Fitzroy     3065 -37.798090  144.979215
# 45       Church     Street          Richmond     3121 -37.829370  144.996400
# 46   Stephenson     Street          Richmond     3121 -37.820335  145.002458
# 47     Victoria     Street          Richmond     3121 -37.809937  144.994548
# 48  St. Georges       Road     Fitzroy north     3068 -37.791351  144.976277
# 49       Grange       Road         Fairfield     3078 -37.779009  145.025109
#
#           LGA                                       SportsPlayed
# 0     WYNDHAM  Netball,Table Tennis,Tennis (Outdoor),Volleyba...
# 1     WYNDHAM                  Netball (Indoor),Cricket (Indoor)
# 2     WYNDHAM  Netball (Indoor),Soccer (Indoor Soccer / Futsa...
# 3     WYNDHAM                           Rugby League,Rugby Union
# 4     WYNDHAM               Rugby Union,Tennis (Outdoor),Netball
# 5     WYNDHAM                                      Soccer,Soccer
# 6     WYNDHAM  Soccer,Tennis (Outdoor),Australian Rules Football
# 7     WYNDHAM                                      Soccer,Soccer
# 8     WYNDHAM  Soccer,Tennis (Outdoor),Australian Rules Footb...
# 9     WYNDHAM                                             Soccer
# 10    WYNDHAM                                   Soccer,Athletics
# 11    WYNDHAM                                   Tennis (Outdoor)
# 12    WYNDHAM  Tennis (Outdoor),Tennis (Outdoor),Australian R...
# 13    WYNDHAM                                   Tennis (Outdoor)
# 14    WYNDHAM                           Tennis (Outdoor),Netball
# 15    WYNDHAM         Tennis (Outdoor),Australian Rules Football
# 16    WYNDHAM         Tennis (Outdoor),Australian Rules Football
# 17    WYNDHAM                                   Tennis (Outdoor)
# 18    WYNDHAM                                   Tennis (Outdoor)
# 19    WYNDHAM         Tennis (Outdoor),Australian Rules Football
# 20    WYNDHAM                                   Tennis (Outdoor)
# 21    WYNDHAM                                   Tennis (Outdoor)
# 22      YARRA                Athletics,Australian Rules Football
# 23      YARRA                      Athletics,Martial Arts,Soccer
# 24      YARRA                          Australian Rules Football
# 25      YARRA                   Australian Rules Football,Soccer
# 26      YARRA                          Australian Rules Football
# 27      YARRA                          Australian Rules Football
# 28      YARRA                          Australian Rules Football
# 29      YARRA                          Australian Rules Football
# 30      YARRA                       Fitness / Gymnasium Workouts
# 31      YARRA                       Fitness / Gymnasium Workouts
# 32      YARRA                       Fitness / Gymnasium Workouts
# 33      YARRA                       Fitness / Gymnasium Workouts
# 34      YARRA                       Fitness / Gymnasium Workouts
# 35      YARRA                       Fitness / Gymnasium Workouts
# 36      YARRA                       Fitness / Gymnasium Workouts
# 37      YARRA                       Fitness / Gymnasium Workouts
# 38      YARRA                       Fitness / Gymnasium Workouts
# 39      YARRA                       Fitness / Gymnasium Workouts
# 40      YARRA                       Fitness / Gymnasium Workouts
# 41      YARRA                       Fitness / Gymnasium Workouts
# 42  MELBOURNE                       Fitness / Gymnasium Workouts
# 43  MELBOURNE                       Fitness / Gymnasium Workouts
# 44      YARRA                       Fitness / Gymnasium Workouts
# 45      YARRA                       Fitness / Gymnasium Workouts
# 46      YARRA                       Fitness / Gymnasium Workouts
# 47      YARRA                       Fitness / Gymnasium Workouts
# 48      YARRA                       Fitness / Gymnasium Workouts
# 49    DAREBIN                       Fitness / Gymnasium Workouts

# %%
new.set_index('Facility_ID', inplace=True)

# %%
# change column names
new.rename(columns={'Facility_ID': 'place_id', 'SportsPlayed':'Type', 'SuburbTown': 'Suburb', 'Longitude':'longitude', 'Latitude': 'latitude'}, inplace=True)

# %%
new.to_csv('sports and reserve_v1.1.csv',encoding='utf8')

# %%
# replace string
data.StreetType = data.StreetType.str.capitalize()

# %%
data.StreetType.unique()

# %%
data[data.StreetType =='Glen']

# %%
# check what it looks like in a api request
# when using longitude and latitude to search back

# %%
lng = df2.iloc[3,:].Longitude
lat = df2.iloc[3,:].Latitude
lng, lat

# %%
df2[df2.SuburbTown.isnull()].shape

# %%
df2[df2.SuburbTown.isnull()]

# %%
data[data.FacilityName =='Leopold Memorial Recreation reserve']

# %%
data[data.FacilityName =='South Barwon reserve']
