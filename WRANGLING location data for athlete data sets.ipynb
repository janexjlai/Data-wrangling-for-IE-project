# %%
# import libraries
import pandas as pd
import requests
#import googlemaps
import numpy as np
import time

# %%
# read in API
with open('google_map_api_key.txt') as f:
    api_key = f.readline()
    f.close
    
api_key
# Out:
# 'AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A'

# %%
# load swimming data
# data source: GFYL swimming data set
athlete = pd.read_csv('tmpccjwGlathletics.csv')
athlete.head(20)
# Out:
#                                          Name  \
# 0   Academy Of Hurdling Incorporating Sprints
# 1                          Athletics Essendon
# 2                        Athletics Nunawading
# 3                          Athletics Waverley
# 4                           Ballarat Harriers
# 5                       Bendigo YMCA Harriers
# 6                 Bill Sewart Athletics Track
# 7                      Box Hill Athletic Club
# 8                 Brunswick Athletic Club Inc
# 9                    Casey Cardinia Athletics
# 10                   Coburg Harriers Club Inc
# 11                       Collingwood Harriers
# 12                        Corio Athletic Club
# 13                       Deakin Athletic Club
# 14               Diamond Valley Athletic Club
# 15                    Doncaster Athletic Club
# 16               Eaglehawk YMCA Athletic Club
# 17                       Eureka Athletic Club
# 18                   Frankston Athletics Club
# 19                       Geelong Walkers Club
#
#                                               Address          Suburb  \
# 0                                318 Pascoe Vale Road        Essendon
# 1                        Moonee Valley Athletic Track    Moonee Ponds
# 2                                                 NaN      Nunawading
# 3                                     Central Reserve   Glen Waverley
# 4   31 Young Street (Overlooking Llanberris Reserve)      Bakery Hill
# 5                                                 NaN         Bendigo
# 6                                           PO Box 76     Forest Hill
# 7                                  Hagenauers Reserve  Box Hill North
# 8                                   342 Albion Street       Brunswick
# 9                             Various training venues             NaN
# 10                                      Outlook Drive          Coburg
# 11                                                NaN    Balwyn North
# 12                                                NaN           Corio
# 13                                                NaN         Geelong
# 14                                      Willinda Park   Greensborough
# 15                 Rieschiecks Reserve, George Street       Doncaster
# 16                                                NaN       Eaglehawk
# 17                                                NaN       Buninyong
# 18                           Ballam Park, Benanee Dve       Frankston
# 19                                Goldsworthy Reserve           Corio
#
#    Postcode State Business Category                                       LGA  \
# 0      3040   VIC    Athletics Club                         Moonee Valley (C)
# 1      3039   VIC    Athletics Club                         Moonee Valley (C)
# 2      3131   VIC    Athletics Club                            Whitehorse (C)
# 3      3150   VIC    Athletics Club                                Monash (C)
# 4      3354   VIC    Athletics Club                              Ballarat (C)
# 5      3552   VIC    Athletics Club  Greater Bendigo (C); Greater Bendigo (C)
# 6      3131   VIC    Athletics Club                                Whitehorse
# 7      3129   VIC    Athletics Club                   Whitehorse , Boroondara
# 8      3056   VIC    Athletics Club                                  Moreland
# 9       NaN   NaN    Athletics Club                             City of Casey
# 10     3058   VIC    Athletics Club                              Moreland (C)
# 11     3104   VIC    Athletics Club                            Boroondara (C)
# 12     3214   VIC    Athletics Club                       Greater Geelong (C)
# 13     3220   VIC    Athletics Club                       Greater Geelong (C)
# 14     3088   VIC    Athletics Club                Nillumbik (S); Banyule (C)
# 15     3108   VIC    Athletics Club                                Manningham
# 16     3556   VIC    Athletics Club                       Greater Bendigo (C)
# 17     3357   VIC    Athletics Club                              Ballarat (C)
# 18     3199   VIC    Athletics Club                             Frankston (C)
# 19     3214   VIC    Athletics Club                       Greater Geelong (C)
#
#                                         Region
# 0           North and West Metropolitan Region
# 1           North and West Metropolitan Region
# 2                  Eastern Metropolitan Region
# 3                  Eastern Metropolitan Region
# 4                             Grampians Region
# 5   Loddon-Mallee Region; Loddon-Mallee Region
# 6                                Eastern Metro
# 7                                Eastern Metro
# 8           North and West Metropolitan Region
# 9                               Southern Metro
# 10          North and West Metropolitan Region
# 11                 Eastern Metropolitan Region
# 12                 Barwon South Western Region
# 13                 Barwon South Western Region
# 14          North and West Metropolitan Region
# 15                               Eastern Metro
# 16                        Loddon-Mallee Region
# 17                            Grampians Region
# 18                Southern Metropolitan Region
# 19                 Barwon South Western Region

# %%
# inspect data set
athlete.shape
# 253 rows of records
# Out:
# (138, 8)

# %%
# check data types of all columns
athlete.dtypes
# Out:
# Name                 object
# Address              object
# Suburb               object
# Postcode             object
# State                object
# Business Category    object
# LGA                  object
# Region               object
# dtype: object

# %%
# check null values
# .any(): 0 return whether attributes contain null or not, 1 return boolean for all records 
athlete[athlete.isnull().any(1)]
#print(swimming[swimming.isnull().any(1)].shape)
# address, LGA, Region column have null values
# Out:
#                                         Name  \
# 2                       Athletics Nunawading
# 5                      Bendigo YMCA Harriers
# 9                   Casey Cardinia Athletics
# 11                      Collingwood Harriers
# 12                       Corio Athletic Club
# 13                      Deakin Athletic Club
# 16              Eaglehawk YMCA Athletic Club
# 17                      Eureka Athletic Club
# 35                     South Coast Athletics
# 37             South Melbourne Athletic Club
# 45                        Athletics Chilwell
# 47               Geelong Guild Athletic Club
# 50       Ballarat YCW Harriers Athletic Club
# 51          Bendigo University Athletic Club
# 52                Geelong Cross Country Club
# 54                    Oakleigh Athletic Club
# 55                     Preston Athletic Club
# 56                         Richmond Harriers
# 57                Ringwood Athletic Club Inc
# 58                      Ruyton Athletic Club
# 59                 Sandringham Athletic Club
# 60                      South West Athletics
# 64            Victorian Cross Country League
# 65                     Victorian Milers Club
# 66               Victorian Race Walking Club
# 68   Wangaratta Harriers Athletics Club Inc.
# 69                   Wendouree Athletic Club
# 70                         Western Athletics
# 71               Williamstown Athletics Club
# 72                     Wodonga Athletic Club
# 74            Ararat Little Athletics Centre
# 90                     Hume Little Athletics
# 112         Oakleigh Little Athletics Centre
#
#                                      Address           Suburb Postcode  \
# 2                                        NaN       Nunawading     3131
# 5                                        NaN          Bendigo     3552
# 9                    Various training venues              NaN      NaN
# 11                                       NaN     Balwyn North     3104
# 12                                       NaN            Corio     3214
# 13                                       NaN          Geelong     3220
# 16                                       NaN        Eaglehawk     3556
# 17                                       NaN        Buninyong     3357
# 35                                       NaN        Leongatha     3953
# 37                                       NaN  South Melbourne      NaN
# 45                                       NaN          Newtown     3220
# 47                                       NaN              NaN      NaN
# 50                                       NaN         Ballarat     3350
# 51                                       NaN              NaN      VIC
# 52   Belmont Park Pavilion, Moorabool Street          Geelong     3220
# 54                                       NaN         Oakleigh     3166
# 55                         Edwards Park Lake        Reservoir     3073
# 56                             Citizens Park         Richmond     3121
# 57                                PO Box 616       Healthmont     3135
# 58                                       NaN              NaN      NaN
# 59                                Glamis Ave          Hampton     3188
# 60              Brauerander Reserve Facility      Warrnambool      NaN
# 64                          64 St Vincent St      Albert Park     3206
# 65                                       NaN              NaN      NaN
# 66                                       NaN              NaN      NaN
# 68                       C/- 10  Alma Avenue       Wangaratta     3677
# 69                                       NaN   Ballarat North      NaN
# 70                                       NaN         Werribee      NaN
# 71             Williamstown Athletics Centre          Newport      NaN
# 72                 Wodonga Athletics Complex          Wodonga      NaN
# 74                                       NaN           Ararat     3377
# 90                     Laura Douglas Reserve          Upfield     3047
# 112                           Davies Reserve   Oakleigh South     3167
#
#         State                                  Business Category  \
# 2         VIC                                     Athletics Club
# 5         VIC                                     Athletics Club
# 9         NaN                                     Athletics Club
# 11        VIC                                     Athletics Club
# 12        VIC                                     Athletics Club
# 13        VIC                                     Athletics Club
# 16        VIC                                     Athletics Club
# 17        VIC                                     Athletics Club
# 35        VIC                                     Athletics Club
# 37        Vic                                     Athletics Club
# 45        VIC                    Athletics Club,Little Athletics
# 47        NaN  Athletics Club,Little Athletics,Sports Club/As...
# 50        VIC             Athletics Club,Sports Club/Association
# 51       3550             Athletics Club,Sports Club/Association
# 52        VIC             Athletics Club,Sports Club/Association
# 54        Vic             Athletics Club,Sports Club/Association
# 55        VIC             Athletics Club,Sports Club/Association
# 56        VIC             Athletics Club,Sports Club/Association
# 57        VIC             Athletics Club,Sports Club/Association
# 58        NaN             Athletics Club,Sports Club/Association
# 59        VIC             Athletics Club,Sports Club/Association
# 60   Victoria             Athletics Club,Sports Club/Association
# 64        VIC             Athletics Club,Sports Club/Association
# 65        NaN             Athletics Club,Sports Club/Association
# 66        NaN             Athletics Club,Sports Club/Association
# 68        VIC             Athletics Club,Sports Club/Association
# 69   Victoria             Athletics Club,Sports Club/Association
# 70   Victoria             Athletics Club,Sports Club/Association
# 71   Victoria             Athletics Club,Sports Club/Association
# 72   Victoria             Athletics Club,Sports Club/Association
# 74        VIC                                   Little Athletics
# 90        VIC                                   Little Athletics
# 112       NaN                                   Little Athletics
#
#                                                 LGA  \
# 2                                    Whitehorse (C)
# 5          Greater Bendigo (C); Greater Bendigo (C)
# 9                                     City of Casey
# 11                                   Boroondara (C)
# 12                              Greater Geelong (C)
# 13                              Greater Geelong (C)
# 16                              Greater Bendigo (C)
# 17                                     Ballarat (C)
# 35                              South Gippsland (S)
# 37   Port Phillip (C); Melbourne (C); Melbourne (C)
# 45                 Greater Geelong (C); Ararat (RC)
# 47                                              NaN
# 50                                              NaN
# 51                                              NaN
# 52                                              NaN
# 54                                              NaN
# 55                                              NaN
# 56                                              NaN
# 57                                              NaN
# 58                                              NaN
# 59                                              NaN
# 60                                  Warrnambool (C)
# 64                                              NaN
# 65                                              NaN
# 66                                              NaN
# 68                                              NaN
# 69                                     Ballarat (C)
# 70            Wyndham (C); Melton (S); Brimbank (C)
# 71                 Maribyrnong (C); Hobsons Bay (C)
# 72         Wodonga (RC); Wodonga (RC); Wodonga (RC)
# 74                                      Ararat (RC)
# 90                                              NaN
# 112                     Kingston (C); Glen Eira (C)
#
#                                                 Region
# 2                          Eastern Metropolitan Region
# 5           Loddon-Mallee Region; Loddon-Mallee Region
# 9                                       Southern Metro
# 11                         Eastern Metropolitan Region
# 12                         Barwon South Western Region
# 13                         Barwon South Western Region
# 16                                Loddon-Mallee Region
# 17                                    Grampians Region
# 35                                    Gippsland Region
# 37   Southern Metropolitan Region; North and West M...
# 45       Barwon South Western Region; Grampians Region
# 47                                                 NaN
# 50                                                 NaN
# 51                                                 NaN
# 52                                                 NaN
# 54                                                 NaN
# 55                                                 NaN
# 56                                                 NaN
# 57                                                 NaN
# 58                                                 NaN
# 59                                                 NaN
# 60                         Barwon South Western Region
# 64                                                 NaN
# 65                                                 NaN
# 66                                                 NaN
# 68                                                 NaN
# 69                                    Grampians Region
# 70                  North and West Metropolitan Region
# 71                  North and West Metropolitan Region
# 72               Hume Region; Hume Region; Hume Region
# 74                                    Grampians Region
# 90                                                 NaN
# 112  Southern Metropolitan Region; Eastern Metropol...

# %%
# deal with address/location columns
# address data consists of four types
# 1. null values, not valid, but can still be used in search query
# 2. address starts with PO: post box address, which are not valid as well
# 3. normal street address, valid
# 4. fitness centre names, valid

# check POST BOX address
# use Series.str.startswith method
athlete[athlete.Address.str.startswith('PO') == True]
# Out:
#                                    Name      Address        Suburb Postcode  \
# 6           Bill Sewart Athletics Track    PO Box 76   Forest Hill     3131
# 34          South Barwon Athletics Club  PO Box 716        Belmont     3216
# 38       Special Olympics Barwon Region  PO Box 1387       Geelong     3220
# 41   Special Olympics Inner East Region   PO Box 181  Surrey Hills     3127
# 42      Special Olympics Bendigo Region   PO Box 201        Huntly     3551
# 57           Ringwood Athletic Club Inc   PO Box 616    Healthmont     3135
# 67               Victorian Road Runners     PO Box48       Burwood     3125
# 100             Little Athletics Centre   PO Box 986          Sale     3850
#
#         State                                  Business Category  \
# 6         VIC                                     Athletics Club
# 34        VIC                                     Athletics Club
# 38        VIC  Athletics Club,Basketball Club,Disability,Gymn...
# 41        VIC  Athletics Club,Basketball Club,Disability,Tenn...
# 42        VIC  Athletics Club,Basketball Club,Disability,Tenp...
# 57        VIC             Athletics Club,Sports Club/Association
# 67   Victoria             Athletics Club,Sports Club/Association
# 100       VIC                                   Little Athletics
#
#                                             LGA                       Region
# 6                                    Whitehorse                Eastern Metro
# 34                              Greater Geelong                   Barwon S/W
# 38                          Greater Geelong (C)  Barwon South Western Region
# 41               Whitehorse (C); Boroondara (C)  Eastern Metropolitan Region
# 42                          Greater Bendigo (C)         Loddon-Mallee Region
# 57                                          NaN                          NaN
# 67   Whitehorse (C); Monash (C); Boroondara (C)  Eastern Metropolitan Region
# 100                                  Wellington                    Gippsland

# %%
# replace all the POST BOX address to null string
athlete.loc[athlete['Address'].str.startswith('PO')==True,'Address'] = np.nan

# %%
# check again
athlete[athlete['Address'].str.startswith('PO')==True]
# Out:
# Empty DataFrame
# Columns: [Name, Address, Suburb, Postcode, State, Business Category, LGA, Region]
# Index: []

# %%
athlete[athlete.isnull().any(1)]
# Out:
#                                         Name  \
# 2                       Athletics Nunawading
# 5                      Bendigo YMCA Harriers
# 6                Bill Sewart Athletics Track
# 9                   Casey Cardinia Athletics
# 11                      Collingwood Harriers
# 12                       Corio Athletic Club
# 13                      Deakin Athletic Club
# 16              Eaglehawk YMCA Athletic Club
# 17                      Eureka Athletic Club
# 34               South Barwon Athletics Club
# 35                     South Coast Athletics
# 37             South Melbourne Athletic Club
# 38            Special Olympics Barwon Region
# 41        Special Olympics Inner East Region
# 42           Special Olympics Bendigo Region
# 45                        Athletics Chilwell
# 47               Geelong Guild Athletic Club
# 50       Ballarat YCW Harriers Athletic Club
# 51          Bendigo University Athletic Club
# 52                Geelong Cross Country Club
# 54                    Oakleigh Athletic Club
# 55                     Preston Athletic Club
# 56                         Richmond Harriers
# 57                Ringwood Athletic Club Inc
# 58                      Ruyton Athletic Club
# 59                 Sandringham Athletic Club
# 60                      South West Athletics
# 64            Victorian Cross Country League
# 65                     Victorian Milers Club
# 66               Victorian Race Walking Club
# 67                    Victorian Road Runners
# 68   Wangaratta Harriers Athletics Club Inc.
# 69                   Wendouree Athletic Club
# 70                         Western Athletics
# 71               Williamstown Athletics Club
# 72                     Wodonga Athletic Club
# 74            Ararat Little Athletics Centre
# 90                     Hume Little Athletics
# 100                  Little Athletics Centre
# 112         Oakleigh Little Athletics Centre
#
#                                      Address           Suburb Postcode  \
# 2                                        NaN       Nunawading     3131
# 5                                        NaN          Bendigo     3552
# 6                                        NaN      Forest Hill     3131
# 9                    Various training venues              NaN      NaN
# 11                                       NaN     Balwyn North     3104
# 12                                       NaN            Corio     3214
# 13                                       NaN          Geelong     3220
# 16                                       NaN        Eaglehawk     3556
# 17                                       NaN        Buninyong     3357
# 34                                       NaN          Belmont     3216
# 35                                       NaN        Leongatha     3953
# 37                                       NaN  South Melbourne      NaN
# 38                                       NaN          Geelong     3220
# 41                                       NaN     Surrey Hills     3127
# 42                                       NaN           Huntly     3551
# 45                                       NaN          Newtown     3220
# 47                                       NaN              NaN      NaN
# 50                                       NaN         Ballarat     3350
# 51                                       NaN              NaN      VIC
# 52   Belmont Park Pavilion, Moorabool Street          Geelong     3220
# 54                                       NaN         Oakleigh     3166
# 55                         Edwards Park Lake        Reservoir     3073
# 56                             Citizens Park         Richmond     3121
# 57                                       NaN       Healthmont     3135
# 58                                       NaN              NaN      NaN
# 59                                Glamis Ave          Hampton     3188
# 60              Brauerander Reserve Facility      Warrnambool      NaN
# 64                          64 St Vincent St      Albert Park     3206
# 65                                       NaN              NaN      NaN
# 66                                       NaN              NaN      NaN
# 67                                       NaN          Burwood     3125
# 68                       C/- 10  Alma Avenue       Wangaratta     3677
# 69                                       NaN   Ballarat North      NaN
# 70                                       NaN         Werribee      NaN
# 71             Williamstown Athletics Centre          Newport      NaN
# 72                 Wodonga Athletics Complex          Wodonga      NaN
# 74                                       NaN           Ararat     3377
# 90                     Laura Douglas Reserve          Upfield     3047
# 100                                      NaN             Sale     3850
# 112                           Davies Reserve   Oakleigh South     3167
#
#         State                                  Business Category  \
# 2         VIC                                     Athletics Club
# 5         VIC                                     Athletics Club
# 6         VIC                                     Athletics Club
# 9         NaN                                     Athletics Club
# 11        VIC                                     Athletics Club
# 12        VIC                                     Athletics Club
# 13        VIC                                     Athletics Club
# 16        VIC                                     Athletics Club
# 17        VIC                                     Athletics Club
# 34        VIC                                     Athletics Club
# 35        VIC                                     Athletics Club
# 37        Vic                                     Athletics Club
# 38        VIC  Athletics Club,Basketball Club,Disability,Gymn...
# 41        VIC  Athletics Club,Basketball Club,Disability,Tenn...
# 42        VIC  Athletics Club,Basketball Club,Disability,Tenp...
# 45        VIC                    Athletics Club,Little Athletics
# 47        NaN  Athletics Club,Little Athletics,Sports Club/As...
# 50        VIC             Athletics Club,Sports Club/Association
# 51       3550             Athletics Club,Sports Club/Association
# 52        VIC             Athletics Club,Sports Club/Association
# 54        Vic             Athletics Club,Sports Club/Association
# 55        VIC             Athletics Club,Sports Club/Association
# 56        VIC             Athletics Club,Sports Club/Association
# 57        VIC             Athletics Club,Sports Club/Association
# 58        NaN             Athletics Club,Sports Club/Association
# 59        VIC             Athletics Club,Sports Club/Association
# 60   Victoria             Athletics Club,Sports Club/Association
# 64        VIC             Athletics Club,Sports Club/Association
# 65        NaN             Athletics Club,Sports Club/Association
# 66        NaN             Athletics Club,Sports Club/Association
# 67   Victoria             Athletics Club,Sports Club/Association
# 68        VIC             Athletics Club,Sports Club/Association
# 69   Victoria             Athletics Club,Sports Club/Association
# 70   Victoria             Athletics Club,Sports Club/Association
# 71   Victoria             Athletics Club,Sports Club/Association
# 72   Victoria             Athletics Club,Sports Club/Association
# 74        VIC                                   Little Athletics
# 90        VIC                                   Little Athletics
# 100       VIC                                   Little Athletics
# 112       NaN                                   Little Athletics
#
#                                                 LGA  \
# 2                                    Whitehorse (C)
# 5          Greater Bendigo (C); Greater Bendigo (C)
# 6                                        Whitehorse
# 9                                     City of Casey
# 11                                   Boroondara (C)
# 12                              Greater Geelong (C)
# 13                              Greater Geelong (C)
# 16                              Greater Bendigo (C)
# 17                                     Ballarat (C)
# 34                                  Greater Geelong
# 35                              South Gippsland (S)
# 37   Port Phillip (C); Melbourne (C); Melbourne (C)
# 38                              Greater Geelong (C)
# 41                   Whitehorse (C); Boroondara (C)
# 42                              Greater Bendigo (C)
# 45                 Greater Geelong (C); Ararat (RC)
# 47                                              NaN
# 50                                              NaN
# 51                                              NaN
# 52                                              NaN
# 54                                              NaN
# 55                                              NaN
# 56                                              NaN
# 57                                              NaN
# 58                                              NaN
# 59                                              NaN
# 60                                  Warrnambool (C)
# 64                                              NaN
# 65                                              NaN
# 66                                              NaN
# 67       Whitehorse (C); Monash (C); Boroondara (C)
# 68                                              NaN
# 69                                     Ballarat (C)
# 70            Wyndham (C); Melton (S); Brimbank (C)
# 71                 Maribyrnong (C); Hobsons Bay (C)
# 72         Wodonga (RC); Wodonga (RC); Wodonga (RC)
# 74                                      Ararat (RC)
# 90                                              NaN
# 100                                      Wellington
# 112                     Kingston (C); Glen Eira (C)
#
#                                                 Region
# 2                          Eastern Metropolitan Region
# 5           Loddon-Mallee Region; Loddon-Mallee Region
# 6                                        Eastern Metro
# 9                                       Southern Metro
# 11                         Eastern Metropolitan Region
# 12                         Barwon South Western Region
# 13                         Barwon South Western Region
# 16                                Loddon-Mallee Region
# 17                                    Grampians Region
# 34                                          Barwon S/W
# 35                                    Gippsland Region
# 37   Southern Metropolitan Region; North and West M...
# 38                         Barwon South Western Region
# 41                         Eastern Metropolitan Region
# 42                                Loddon-Mallee Region
# 45       Barwon South Western Region; Grampians Region
# 47                                                 NaN
# 50                                                 NaN
# 51                                                 NaN
# 52                                                 NaN
# 54                                                 NaN
# 55                                                 NaN
# 56                                                 NaN
# 57                                                 NaN
# 58                                                 NaN
# 59                                                 NaN
# 60                         Barwon South Western Region
# 64                                                 NaN
# 65                                                 NaN
# 66                                                 NaN
# 67                         Eastern Metropolitan Region
# 68                                                 NaN
# 69                                    Grampians Region
# 70                  North and West Metropolitan Region
# 71                  North and West Metropolitan Region
# 72               Hume Region; Hume Region; Hume Region
# 74                                    Grampians Region
# 90                                                 NaN
# 100                                          Gippsland
# 112  Southern Metropolitan Region; Eastern Metropol...

# %%
# check business types
athlete['Business Category'].unique()
# Little Athletics: Australian program which offer sport programs for kids aged from 5 to 15
# Out:
# array(['Athletics Club',
#        'Athletics Club,Basketball Club,Disability,Gymnastics,Tennis club,Tenpin Bowling',
#        'Athletics Club,Basketball Club,Disability,Softball Club',
#        'Athletics Club,Basketball Club,Disability,Softball Club,Tennis club',
#        'Athletics Club,Basketball Club,Disability,Tennis club,Tenpin Bowling',
#        'Athletics Club,Basketball Club,Disability,Tenpin Bowling',
#        'Athletics Club,Disability,Sports Club/Association',
#        'Athletics Club,Disability,Tennis club,Tenpin Bowling',
#        'Athletics Club,Little Athletics',
#        'Athletics Club,Little Athletics,Sports Club/Association',
#        'Athletics Club,Recreation Group',
#        'Athletics Club,Sports Club/Association', 'Little Athletics'],
#       dtype=object)

# %%
# create the search query
# test
##

# examp: example for the search query
# examp2: example for the search query when results are more than one page
examp = 'https://maps.googleapis.com/maps/api/place/textsearch/json?query={}&key={}'
examp2 = 'https://maps.googleapis.com/maps/api/place/textsearch/json?query={}&pagetoken={}&key={}'
print(examp)
print(examp2)

# initialize variables
name = ''
add = ''
sub = ''
nextpage = ''

# dataframe to store the new data
athlete_check = pd.DataFrame(columns=['orgName', 'orgAddress', 'searchquery', 'Name', 'formattedAddress',
                                       'State', 'Business Category', 'longitude', 'latitude', 'type',
                                       'status_code', 'next_page_token', 'price_level', 'rating', 
                                       'opennow', 'permanent_closed',
                                       'place_id'])

for i in range(athlete.shape[0]):
    # assign row values to variables to form search query
    name = athlete.loc[i,:].Name
    add = athlete.loc[i,:].Address
    sub = athlete.loc[i,:].Suburb
    b_types = athlete.loc[i,:]['Business Category']
    q = '+'.join('' if str(name)=='nan' else name.split()) \
    + '+' \
    + '+'.join('' if str(add)=='nan' else add.split()) \
    + '+' \
    + '+'.join('' if str(sub)=='nan' else sub.split())
    #print(q)
    # format the search query
    q_send = examp.format(q, api_key)
    print(q_send)
    new_row = {}
    results = ''
    
    # start processing
    results = requests.get(q_send).json()
    #print(results)
    thispage = results.get('results')
    
    # if returned results have more than one page
    # use while loop and store next_page_token 
    while results.get('next_page_token') is not None:
        # variable to store token
        nextpage= results.get('next_page_token')
        print(nextpage)
        for j in range(len(thispage)):
            new_row = { 'orgName': name,
                        'orgAddress': add,
                        'Name': thispage[j].get('name'),
                        'searchquery': q,
                        'formattedAddress': thispage[j].get('formatted_address'),
                        # there are cases that return result is actually null
                        # therefore [] in postcode can indicate null result
                        #'Postcode': [p.get('short_name') for p in thispage[i].get('address_components') if p.get('types') == ['postal_code']],
                        #'Suburb/locality': [p.get('long_name') for p in thispage[i].get('address_components') if 'locality' in p.get('types')][0],
                        'State': 'VIC',
                        'Business Category': b_types,
                        'longitude': thispage[j].get('geometry').get('location').get('lng'),
                        'latitude': thispage[j].get('geometry').get('location').get('lat'),
                        'status_code': results.get('status'),
                        'type': thispage[j].get('types'),
                        'next_page_token': nextpage,
                        'price_level': thispage[j].get('price_level'),
                        'rating': thispage[j].get('rating'),
                        'opennow': None if thispage[j].get('opening_hours') is None else thispage[j].get('opening_hours').get('open_now'),
                        'permanent_closed': thispage[j].get('permanently_closed'),
                        'place_id': thispage[j].get('place_id')

            }
            
            # append new result to output dataframe
            #print(new_row)
            athlete_check = athlete_check.append(new_row, ignore_index= True)

        # send next page request
        # overwrite the parameters
        q_send_next = examp2.format(q,nextpage,api_key)
        # wait one second for the next token to validate
        # and send request again
        time.sleep(3)
        results = requests.get(q_send_next).json()
        thispage = results.get('results')
        #print(results.get('next_page_token'))
        #print(len(thispage))
    
    # for the rest page
    # if there is no result in the page
    if len(thispage) == 0:
        new_row =  {'orgName': name,
                    'orgAddress': add,
                    'Name': name,
                    'searchquery': q,
                    'formattedAddress': None,
                    # there are cases that return result is actually null
                    # therefore [] in postcode can indicate null result
                    #'Postcode': None,
                    #'Suburb/locality': None,
                    'State': 'VIC',
                    'Business Category': None,
                    'longitude': None,
                    'latitude': None,
                    'status_code': results.get('status'),
                    'type': None,
                    'next_page_token': None,
                    'price_level': None,
                    'rating': None,
                    'opennow': None,
                    'permanent_closed': None,
                    'place_id': None

                   }
        
        # append new result to output dataframe
        #print(new_row)
        athlete_check = athlete_check.append(new_row, ignore_index= True)
        
        
    # if page result is less than 20   
    else:  
        for j in range(len(thispage)):
            new_row = { 'orgName': name,
                        'orgAddress': add,
                        'Name': thispage[j].get('name'),
                        'searchquery': q,
                        'formattedAddress': thispage[j].get('formatted_address'),
                        # there are cases that return result is actually null
                        # therefore [] in postcode can indicate null result
                        #'Postcode': [p.get('short_name') for p in thispage[i].get('address_components') if p.get('types') == ['postal_code']],
                        #'Suburb/locality': [p.get('long_name') for p in thispage[i].get('address_components') if 'locality' in p.get('types')][0],
                        'State': 'VIC',
                        'Business Category': b_types,
                        'longitude': thispage[j].get('geometry').get('location').get('lng'),
                        'latitude': thispage[j].get('geometry').get('location').get('lat'),
                        'status_code': results.get('status'),
                        'type': thispage[j].get('types'),
                        'next_page_token': nextpage,
                        'price_level': thispage[j].get('price_level'),
                        'rating': thispage[j].get('rating'),
                        'opennow': None if thispage[j].get('opening_hours') is None else thispage[j].get('opening_hours').get('open_now'),
                        'permanent_closed': thispage[j].get('permanently_closed'),
                        'place_id': thispage[j].get('place_id')

            }
            
            # append new result to output dataframe
            #print(new_row)
            athlete_check = athlete_check.append(new_row, ignore_index= True)

    
    
    # test for several queries
    # uncomemnt for testing
    #if i == 5:
        #break
# Out:
# https://maps.googleapis.com/maps/api/place/textsearch/json?query={}&key={}
# https://maps.googleapis.com/maps/api/place/textsearch/json?query={}&pagetoken={}&key={}
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Academy+Of+Hurdling+Incorporating+Sprints+318+Pascoe+Vale+Road+Essendon&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Athletics+Essendon+Moonee+Valley+Athletic+Track+Moonee+Ponds&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Athletics+Nunawading++Nunawading&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Athletics+Waverley+Central+Reserve+Glen+Waverley&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ballarat+Harriers+31+Young+Street+(Overlooking+Llanberris+Reserve)+Bakery+Hill&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Bendigo+YMCA+Harriers++Bendigo&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Bill+Sewart+Athletics+Track++Forest+Hill&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Box+Hill+Athletic+Club+Hagenauers+Reserve+Box+Hill+North&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Brunswick+Athletic+Club+Inc+342+Albion+Street+Brunswick&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Casey+Cardinia+Athletics+Various+training+venues+&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Coburg+Harriers+Club+Inc+Outlook+Drive+Coburg&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Collingwood+Harriers++Balwyn+North&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Corio+Athletic+Club++Corio&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Deakin+Athletic+Club++Geelong&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Diamond+Valley+Athletic+Club+Willinda+Park+Greensborough&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Doncaster+Athletic+Club+Rieschiecks+Reserve,+George+Street+Doncaster&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Eaglehawk+YMCA+Athletic+Club++Eaglehawk&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Eureka+Athletic+Club++Buninyong&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Frankston+Athletics+Club+Ballam+Park,+Benanee+Dve+Frankston&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Geelong+Walkers+Club+Goldsworthy+Reserve+Corio&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Gippsland+Athletics+Club+Joe+Carmody+Athletics+Track+Newborough&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Glenhuntly+Athletic+Club+Inc+Duncan+MacKinnon+Reserve+Murrumbeena&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Haileybury+Athletic+Club+Ross+Reserve+Springvale&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Ivanhoe+Harriers+Athletic+Club+Inc.+Willinda+Park,+Beatrix+St+Greensborough&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Keilor+St.+Bernard's+Athletic+Club+45a+Glass+Street+Essendon&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Knox+Athletics+Club+Knox+Athletics+Track+Knoxfield&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Knox+Road+Runners+Inc+Community+Youth+Centre+Bayswater&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Knox+Sherbrooke+Womens+Athletic+Club+32+Bunnett+Road+Knoxfield&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Maccabi+Athletic+Club+Duncan+MacKinnon+Athletic+Grounds+Murrumbeena&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Malvern+Harriers+Athletic+Club+Kooyong+Park+Malvern&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Melbourne+Track+Club+Level+2,+70+Jolimont+Street+Jolimont&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Mentone+Athletic+Club+Dolarmore+Oval+Mentone&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Moonee+Ponds+Athletic+Track+Corio+Street+Moonee+Ponds&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Mornington+Peninsula+Athletics+Club+Ballam+Park+Frankston&key=AIzaSyD_FQ8TfTJQ4CVYXBUPm70uYyvU3WZ2g3A
# https://maps.googleapis.com/maps/api/place/textsearch/json?query
# 204           Pakenham Little Athletics Centre
# 205         Preston/Reservoir Little Athletics
# 206           Ringwood Little Athletics Centre
# 207           Ringwood Little Athletics Centre
# 208          Rochester Little Athletics Centre
# 209        Sandringham Little Athletics Centre
# 210            Seaford Little Athletics Centre
# 211            Seymour Little Athletics Centre
# 212         Shepparton Little Athletics Centre
# 213         Shepparton Little Athletics Centre
# 214         Sherbrooke Little Athletics Centre
# 215         Springvale Little Athletics Centre
# 216          St Arnaud Little Athletics Centre
# 217          St Arnaud Little Athletics Centre
# 218       Sunbury Little Athletics Centre Inc.
# 219          Swan Hill Little Athletics Centre
# 220          Traralgon Little Athletics Centre
# 221         Wangaratta Little Athletics Centre
# 222           Warragul Little Athletics Centre
# 223        Warrnambool Little Athletics Centre
# 224                  Waverley Little Athletics
# 225             Werribee Little Athletics Club
# 226               Westernport Little Athletics
# 227    Whittlesea City Little Athletics Centre
# 228    Whittlesea City Little Athletics Centre
# 229       Williamstown Little Athletics Centre
# 230                 Wonthaggi Little Athletics
# 231            Woodend Little Athletics Centre
#
#                                             orgAddress  \
# 0                                 318 Pascoe Vale Road
# 1                         Moonee Valley Athletic Track
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                      Central Reserve
# 6                                      Central Reserve
# 7    31 Young Street (Overlooking Llanberris Reserve)
# 8                                                  NaN
# 9                                                  NaN
# 10                                  Hagenauers Reserve
# 11                                  Hagenauers Reserve
# 12                                   342 Albion Street
# 13                             Various training venues
# 14                                       Outlook Drive
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 202                                     Davies Reserve
# 203                      Orbost Secondary College Oval
# 204                                     Toomuc Reserve
# 205                                 Edwardes Park Lake
# 206                                  Proclamation Park
# 207                                  Proclamation Park
# 208        Rochester Recreation Reserve Windridge Oval
# 209                                      Glamis Avenue
# 210                                       Riviera Park
# 211                                      Chittick Park
# 212                                     McEwen Reserve
# 213                                     McEwen Reserve
# 214                                         Kings Park
# 215                        Ross Reserve Memorial Drive
# 216                                   Lord Nelson Park
# 217                                   Lord Nelson Park
# 218                     Eric Boardman Memorial Reserve
# 219                      Ken Harrison Sporting Complex
# 220                                Harold Preston Park
# 221                                         Appin Park
# 222                                   Geoff Watt Track
# 223                                Lake Pertobe Centre
# 224                                    Central Reserve
# 225                      VU & Wyndham Sporting Complex
# 226                      Westernport Secondary College
# 227                       Meadowglen Athletics Stadium
# 228                       Meadowglen Athletics Stadium
# 229                                       Newport Park
# 230                       Bilson Street Primary School
# 231                Oval Next to Buffalo Sports Stadium
#
#                                            searchquery  \
# 0    Academy+Of+Hurdling+Incorporating+Sprints+318+...
# 1    Athletics+Essendon+Moonee+Valley+Athletic+Trac...
# 2                     Athletics+Nunawading++Nunawading
# 3                     Athletics+Nunawading++Nunawading
# 4                     Athletics+Nunawading++Nunawading
# 5     Athletics+Waverley+Central+Reserve+Glen+Waverley
# 6     Athletics+Waverley+Central+Reserve+Glen+Waverley
# 7    Ballarat+Harriers+31+Young+Street+(Overlooking...
# 8                       Bendigo+YMCA+Harriers++Bendigo
# 9             Bill+Sewart+Athletics+Track++Forest+Hill
# 16          40 Broderick Rd, Corio VIC 3214, Australia   VIC
# 17               Purnell Rd, Corio VIC 3214, Australia   VIC
# 18     Hendy Street Reserve, Corio VIC 3214, Australia   VIC
# 19               Purnell Rd, Corio VIC 3214, Australia   VIC
# 20                           Corio VIC 3214, Australia   VIC
# 21             Foreshore Rd, Corio VIC 3214, Australia   VIC
# 22              20 Hendy St, Corio VIC 3214, Australia   VIC
# 23            76 Purnell Rd, Corio VIC 3214, Australia   VIC
# 24               6 Johns St, Corio VIC 3214, Australia   VIC
# 25     118 Bacchus Marsh Rd, Corio VIC 3214, Australia   VIC
# 26   Stead Park Station St, Norlane VIC 3214, Austr...   VIC
# 27               1 Cox Rd, Norlane VIC 3214, Australia   VIC
# 28        6/8 Lambert Ave, Newtown VIC 3220, Australia   VIC
# 29        1 Gheringhap St, Geelong VIC 3220, Australia   VIC
# ..                                                 ...   ...
# 202  Cnr North and Murrumbeena Rd Duncan Mackinnon ...   VIC
# 203            2 Arnold St, Orbost VIC 3888, Australia   VIC
# 204         Unnamed Road, Pakenham VIC 3810, Australia   VIC
# 205                                               None   VIC
# 206         Sylvia Grove, Ringwood VIC 3134, Australia   VIC
# 207   11-13 Sylvia Grove, Ringwood VIC 3134, Australia   VIC
# 208                                               None   VIC
# 209            Glamis Ave, Hampton VIC 3188, Australia   VIC
# 210  Riviera Reserve, Eel Race Rd, Seaford VIC 3198...   VIC
# 211                                               None   VIC
# 212     Numurkah Road,, Shepparton VIC 3630, Australia   VIC
# 213       4 Brauman St, Shepparton VIC 3630, Australia   VIC
# 214           Upper Ferntree Gully VIC 3156, Australia   VIC
# 215  Ross Reserve, 44 Memorial Dr, Noble Park VIC 3...   VIC
# 216       26 Dunstan St, St Arnaud VIC 3478, Australia   VIC
# 217                      St Arnaud VIC 3478, Australia   VIC
# 218                                               None   VIC
# 219                                               None   VIC
# 220  Harold Preston Reserve, Davidson Street, Trara...   VIC
# 221       149 Appin St, Wangaratta VIC 3677, Australia   VIC
# 222       47/61 Burke St, Warragul VIC 3820, Australia   VIC
# 223                    Warrnambool VIC 3280, Australia   VIC
# 224  Central Reserve, Glen Waverley VIC 3150, Austr...   VIC
# 225  Victoria Universitiy Wyndham Sporting Complex ...   VIC
# 226                                               None   VIC
# 227   156-176 McDonalds Rd, Epping VIC 3076, Australia   VIC
# 228   146/156 McDonalds Rd, Epping VIC 3076, Australia   VIC
# 229  Corner &, The Strand & North Rd, Newport VIC 3...   VIC
# 230  107/105 S Dudley Rd, Wonthaggi VIC 3995, Austr...   VIC
# 231        1-29 Forest St, Woodend VIC 3442, Australia   VIC
#
#     Business Category longitude latitude  \
# 0                None       NaN      NaN
# 1      Athletics Club   144.902 -37.7622
# 2      Athletics Club   145.163 -37.8567
# 3      Athletics Club   145.184 -37.8169
# 4      Athletics Club   145.163 -37.8567
# 5      Athletics Club   145.162 -37.8919
# 6      Athletics Club    145.16 -37.8922
# 7      Athletics Club   143.865 -37.5699
# 8                None      None     None
# 9      Athletics Club   145.163 -37.8567
# 10     Athletics Club   145.118 -37.8095
# 11     Athletics Club   145.118 -37.8104
# 12     Athletics Club   144.952 -37.7598
# 13               None      None     None
# 14     Athletics Club   144.977 -37.7331
# 15               None      None     None
# 16     Athletics Club   144.381 -38.0617
# 17     Athletics Club   144.353 -38.0735
# 18     Athletics Club   144.367 -38.0663
# 19     Athletics Club   144.362 -38.0739
# 20     Athletics Club   144.364 -38.0826
# 21     Athletics Club   144.406 -38.0716
# 22     Athletics Club   144.366 -38.0727
# 23     Athletics Club    144.36 -38.0727
# 24     Athletics Club   144.364 -38.0843
# 25     Athletics Club   144.359 -38.0744
# 26     Athletics Club   144.367 -38.0829
# 27     Athletics Club   144.356 -38.0843
# 28     Athletics Club   144.339 -38.1599
# 29     Athletics Club    144.36 -38.1434
# ..                ...       ...      ...
# 202  Little Athletics   145.064 -37.9062
# 203  Little Athletics   148.467 -37.7042
# 204  Little Athletics   145.458  -38.066
# 205              None      None     None
# 206  Little Athletics   145.222 -37.8271
# 207  Little Athletics   145.222 -37.8286
# 208              None      None     None
# 209  Little Athletics   145.017 -37.9392
# 210  Little Athletics   145.132 -38.0841
# 211              None      None     None
# 212  Little Athletics     145.4 -36.3562
# 213  Little Athletics   145.395 -36.3571
# 214  Little Athletics   145.301 -37.8943
# 215  Little Athletics   145.172 -37.9598
# 216  Little Athletics    143.26 -36.6095
# 217  Little Athletics   143.261  -36.611
# 218              None      None     None
# 219              None      None     None
# 220  Little Athletics   146.542 -38.1902
# 221  Little Athletics     146.3 -36.3421
# 222  Little Athletics   145.926 -38.1649
# 223  Little Athletics   142.474 -38.3923
# 224  Little Athletics    145.16 -37.8922
# 225  Little Athletics   144.702 -37.8926
# 226              None      None     None
# 227  Little Athletics   145.058 -37.6462
# 228  Little Athletics   145.056 -37.6477
# 229  Little Athletics   144.895 -37.8441
# 230  Little Athletics   145.581 -38.5918
# 231  Little Athletics   144.522 -37.3533
#
#                                                   type   status_code  \
# 0                                                 None  ZERO_RESULTS
# 1                   [point_of_interest, establishment]            OK
# 2                   [point_of_interest, establishment]            OK
# 3      [gym, health, point_of_interest, establishment]            OK
# 4                   [point_of_interest, establishment]            OK
# 5                   [point_of_interest, establishment]            OK
# 6                   [point_of_interest, establishment]            OK
# 7                   [point_of_interest, establishment]            OK
# 8                                                 None  ZERO_RESULTS
# 9                   [point_of_interest, establishment]            OK
# 10            [park, point_of_interest, establishment]            OK
# 11     [gym, health, point_of_interest, establishment]            OK
# 12                  [point_of_interest, establishment]            OK
# 13                                                None  ZERO_RESULTS
# 14                  [point_of_interest, establishment]            OK
# 15                                                None  ZERO_RESULTS
# 16                  [point_of_interest, establishment]            OK
# 17                  [point_of_interest, establishment]            OK
# 18      [university, point_of_interest, establishment]            OK
# 19                  [point_of_interest, establishment]            OK
# 20                  [point_of_interest, establishment]            OK
# 21                  [point_of_interest, establishment]            OK
# 22                  [point_of_interest, establishment]            OK
# 23   [restaurant, point_of_interest, food, establis...            OK
# 24             [bar, point_of_interest, establishment]            OK
# 25          [health, point_of_interest, establishment]            OK
# 26                  [point_of_interest, establishment]            OK
# 27      [university, point_of_interest, establishment]            OK
# 28           [store, point_of_interest, establishment]            OK
# 29                  [point_of_interest, establishment]            OK
# ..                                                 ...           ...
# 202                 [point_of_interest, establishment]            OK
# 203         [point_of_interest, school, establishment]            OK
# 204    [gym, health, point_of_interest, establishment]            OK
# 205                                               None  ZERO_RESULTS
# 206                 [point_of_interest, establishment]            OK
# 207                 [point_of_interest, establishment]            OK
# 208                                               None  ZERO_RESULTS
# 209    [gym, health, point_of_interest, establishment]            OK
# 210    [gym, health, point_of_interest, establishment]            OK
# 211                                               None  ZERO_RESULTS
# 212                 [point_of_interest, establishment]            OK
# 213    [gym, health, point_of_interest, establishment]            OK
# 214         [school, point_of_interest, establishment]            OK
# 215                 [point_of_interest, establishment]            OK
# 216  [bar, restaurant, point_of_interest, food, est...            OK
# 217           [park, point_of_interest, establishment]            OK
# 218                                               None  ZERO_RESULTS
# 219                                               None  ZERO_RESULTS
# 220                 [point_of_interest, establishment]            OK
# 221         [point_of_interest, school, establishment]            OK
# 222                 [point_of_interest, establishment]            OK
# 223                 [point_of_interest, establishment]            OK
# 224                 [point_of_interest, establishment]            OK
# 225                 [point_of_interest, establishment]            OK
# 226                                               None  ZERO_RESULTS
# 227                 [point_of_interest, establishment]            OK
# 228                 [point_of_interest, establishment]            OK
# 229                 [point_of_interest, establishment]            OK
# 230    [gym, health, point_of_interest, establishment]            OK
# 231        [stadium, point_of_interest, establishment]            OK
#
#                                        next_page_token price_level rating  \
# 0                                                 None        None    NaN
# 1                                                             None    4.6
# 2                                                             None      0
# 3                                                             None    4.7
# 4                                                             None    4.1
# 5                                                             None    4.3
# 6                                                             None    4.8
# 7                                                             None      0
# 8                                                 None        None   None
# 9                                                             None    4.1
# 10                                                            None    4.4
# 11                                                            None    3.6
# 12                                                            None      5
# 13                                                None        None   None
# 14                                                            None    4.3
# 15                                                None        None   None
# 16                                                            None    4.1
# 17                                                            None      4
# 18                                                            None      5
# 19                                                            None    3.4
# 20                                                            None      5
# 21                                                            None    4.5
# 22                                                            None    4.3
# 23                                                               2      4
# 24                                                               1    4.7
# 25                                                            None      5
# 26                                                            None    4.2
# 27                                                            None    3.5
# 28                                                            None      0
# 29                                                            None    4.8
# ..                                                 ...         ...    ...
# 202  CpQCDwEAAFhYG3vAd46jjcJ_ChG34zg4o_vCujjFrp-k_m...        None      0
# 203  CpQCDwEAAFhYG3vAd46jjcJ_ChG34zg4o_vCujjFrp-k_m...        None      0
# 204  CpQCDwEAAFhYG3vAd46jjcJ_ChG34zg4o_vCujjFrp-k_m...        None      5
# 205                                               None        None   None
# 206  CpQCDwEAAFhYG3vAd46jjcJ_ChG34zg4o_vCujjFrp-k_m...        None    3.6
# 207  CpQCDwEAAFhYG3vAd46jjcJ_ChG34zg4o_vCujjFrp-k_m...        None    4.1
# 208                                               None        None   None
# 209  CpQCDwEAAFhYG3vAd46jjcJ_ChG34zg4o_vCujjFrp-k_m...        None    3.9
# 210  CpQCDwEAAFhYG3vAd46jjcJ_ChG34zg4o_vCujjFrp-k_m...        None      5
# 211                                               None        None   None
# 212  CpQCDwEAAFhYG3vAd46jjcJ_ChG34zg4o_vCujjFrp-k_m...        None      4
# 213  CpQCDwEAAFhYG3vAd46jjcJ_ChG34zg4o_vCujjFrp-k_m...        None    3.8
# 214  CpQCDwEAAFhYG3vAd46jjcJ_ChG34zg4o_vCujjFrp-k_m...        None      0
# 215  CpQCDwEAAFhYG3vAd46jjcJ_ChG34zg4o_vCujjFrp-k_m...        None    4.2
# 216  CpQCDwEAAFhYG3vAd46jjcJ_ChG34zg4o_vCujjFrp-k_m...        None    4.3
# 217  CpQCDwEAAFhYG3vAd46jjcJ_ChG34zg4o_vCujjFrp-k_m...        None    4.3
# 218                                               None        None   None
# 219                                               None        None   None
# 220  CpQCDwEAAFhYG3vAd46jjcJ_ChG34zg4o_vCujjFrp-k_m...        None    4.8
# 221  CpQCDwEAAFhYG3vAd46jjcJ_ChG34zg4o_vCujjFrp-k_m...        None      5
# 222  CpQCDwEAAFhYG3vAd46jjcJ_ChG34zg4o_vCujjFrp-k_m...        None      3
# 223  CpQCDwEAAFhYG3vAd46jjcJ_ChG34zg4o_vCujjFrp-k_m...        None      0
# 224  CpQCDwEAAFhYG3vAd46jjcJ_ChG34zg4o_vCujjFrp-k_m...        None    4.8
# 225  CpQCDwEAAFhYG3vAd46jjcJ_ChG34zg4o_vCujjFrp-k_m...        None    4.6
# 226                                               None        None   None
# 227  CpQCDwEAAFhYG3vAd46jjcJ_ChG34zg4o_vCujjFrp-k_m...        None    4.7
# 228  CpQCDwEAAFhYG3vAd46jjcJ_ChG34zg4o_vCujjFrp-k_m...        None    4.2
# 229  CpQCDwEAAFhYG3vAd46jjcJ_ChG34zg4o_vCujjFrp-k_m...        None    4.6
# 230  CpQCDwEAAFhYG3vAd46jjcJ_ChG34zg4o_vCujjFrp-k_m...        None      0
# 231  CpQCDwEAAFhYG3vAd46jjcJ_ChG34zg4o_vCujjFrp-k_m...        None    4.3
#
#     opennow permanent_closed                     place_id
# 0      None             None                         None
# 1     False             None  ChIJ182vuUVc1moRTkoEpd8tnbE
# 2      None             None  ChIJ4Ti7qEQ_1moR4qgbKbKVj5g
# 3      True             None  ChIJq6qqJiE51moRzrJiQMnA2oo
# 4      True             None  ChIJI_zHqAw_1moRWgfGlu9NFeQ
# 5      True             None  ChIJv3MeCt0_1moRh2iu4rJi6yI
# 6      None             None  ChIJAdrG8t0_1moRegMgM93ITto
# 7      None             None  ChIJAYPMA_1E0WoRzRQmO1p65_s
# 8      None             None                         None
# 9      True             None  ChIJI_zHqAw_1moRWgfGlu9NFeQ
# 10     None             None  ChIJIRkDJrVA1moR6zl6CTZK6cU
# 11     True             None  ChIJmQRwELVA1moRwYbObcK7QEo
# 12     True             None  ChIJFXKlB69c1moRhHGqdLZ8j_o
# 13     None             None                         None
# 14     None             None  ChIJr-Qel7RE1moRQhDP_jj5bxk
# 15     None             None                         None
# 16     None             None  ChIJq6qqWsgZ1GoRe-Sk7avljMg
# 17     None             None  ChIJF3KcRFEX1GoR3H0Oliph_jQ
# 18    False             None  ChIJ____D-cZ1GoRjPDtDCaNZCI
# 19     None             None  ChIJIZ-qKFkX1GoR8ogf1nXU3Ew
# 20    False             None  ChIJLy50b0MX1GoRwS9kPz8adGs
# 21     None             None  ChIJXx6IZjkY1GoR49CLMpTnpA0
# 22     True             None  ChIJnTGih18X1GoRWb7SGW6_FSc
# 23     True             None  ChIJZ7TBrFkX1GoRC5gJ3l11vac
# 24    False             None  ChIJIWiWjUMX1GoRME7_ZCirKTc
# 25    False             None  ChIJ6UlOjFkX1GoRtA-75UG93f4
# 26     None             None  ChIJHQygxkIX1GoRv783zLVKxlU
# 27     None             None  ChIJ11aZYs8W1GoRsYiy4T_QFpI
# 28    False             None  ChIJHaMyL4wT1GoRrBgcpOtuA3U
# 29    False             None  ChIJtwWUCqcW1GoR4ZT_t_v7XSA
# ..      ...              ...                          ...
# 202    None             None  ChIJARpm9Jpr1moRX6bBl8srtLM
# 203    None             None  ChIJxYRwNIbJOmsR3wrXemYUeh4
# 204    None             None  ChIJIw9of3oe1moROZPaechHrqU
# 205    None             None                         None
# 206    None             None  ChIJR6fjOF451moRMCf0bTefY6g
# 207    True             None  ChIJ7aVB81451moR8IgxBXZWBA8
# 208    None             None                         None
# 209   False             None  ChIJSTqr1Nxu1moRSDal3vHTd5U
# 210   False             None  ChIJbzNgBy5z1moRiBADUrF3oDQ
# 211    None             None                         None
# 212    None             None  ChIJzbykIH-E2GoRheFlLB4BH68
# 213   False             None  ChIJq1IEqHuE2GoRJUExbk23Z1E
# 214   False             None  ChIJ5XunLlE91moRc-RUjoIyu_4
# 215    None             None  ChIJr7BfDI0U1moRf8GleC_cG2c
# 216    True             None  ChIJAQAABKhn0GoRIO8fNgv_RDc
# 217    None             None  ChIJsVgXBqhn0GoREAxDFKV5BQ8
# 218    None             None                         None
# 219    None             None                         None
# 220    True             None  ChIJoaywXhYYKWsR9c90L5Nc54Q
# 221    None             None  ChIJeS-x7tvbJmsRX-PKtg4CRRY
# 222    None             None  ChIJV0lrn-WVKWsRWFRtP9XxqiI
# 223    None             None  ChIJC6ILie5MzWoRTLgfLaIOjwc
# 224    None             None  ChIJAdrG8t0_1moRegMgM93ITto
# 225    None             None  ChIJo-CCkwGG1moRPU7hbvJtza8
# 226    None             None                         None
# 227    None             None  ChIJofMOUVBJ1moR0JtUWOywNSE
# 228   False             None  ChIJofMOUVBJ1moRQHTNZeOqKak
# 229    None             None  ChIJ7xpEASBn1moRJH3tZRsuLY0
# 230    None             None  ChIJ1TsRjngMKmsRDvqu-Y26b-4
# 231    None             None  ChIJ6T9KLNgd12oRl8Tbria5fQs
#
# [232 rows x 17 columns]

# %%
athlete_check.shape
# Out:
# (232, 17)

# %%
athlete_check.status_code.unique()
# Out:
# array(['ZERO_RESULTS', 'OK'], dtype=object)

# %%
# write results to csv
athlete_check.to_csv('athlete club location information v1_0.csv', encoding='utf-8')
